# %%
import os,shutil

# %%
os.environ['KAGGLE_USERNAME']='rohanazad'
os.environ['KAGGLE_KEY']='f3cf3c594532e397b78564e4bbe88ec6'

# %%
# !kaggle competitions download -c ashrae-energy-prediction
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# sample_submission.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# test.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# building_metadata.csv: Skipping, found more recently modified local copy (use --force to force download)
# weather_test.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# weather_train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import pandas as pd

# %%
import zipfile

unzipped_train=zipfile.ZipFile('train.csv.zip')
unzipped_train.extractall()
unzipped_train.close()

unzipped_test=zipfile.ZipFile('test.csv.zip')
unzipped_test.extractall()
unzipped_test.close()

# %%
# unzipped_weather_train=zipfile.ZipFile('weather_train.csv.zip')
# unzipped_weather_train.extractall()
# unzipped_weather_train.close()

# unzipped_weather_test=zipfile.ZipFile('weather_test.csv.zip')
# unzipped_weather_test.extractall()
# unzipped_weather_test.close()

# %%
# weather_train=pd.read_csv('weather_train.csv')
# weather_test=pd.read_csv('weather_test.csv')
# building_met=pd.read_csv('building_metadata.csv')

# %%
# total=weather_train.isnull().sum().sort_values(ascending=False)
# percent=(weather_train.isnull().sum()/weather_train.isnull().count()).sort_values(ascending=False)
# missing_values=pd.concat([total,percent],axis=1,keys=['total','percent'])
# missing_values.head(20)

# %%
# total=building_met.isnull().sum().sort_values(ascending=False)
# percent=(building_met.isnull().sum()/building_met.isnull().count()).sort_values(ascending=False)
# missing_values=pd.concat([total,percent],axis=1,keys=['total','percent'])
# missing_values.head(20)

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')
weather_train_dir='/content/drive/My Drive/weather_train3.csv'
weather_train=pd.read_csv(weather_train_dir)
weather_test_dir='/content/drive/My Drive/weather_test2.csv'
weather_test=pd.read_csv(weather_test_dir)
building_met_dir='/content/drive/My Drive/building_metadata_save.csv'
building_met=pd.read_csv(building_met_dir)

# %%
# total=train.isnull().sum().sort_values(ascending=False)
# percent=(train.isnull().sum()/train.isnull().count()).sort_values(ascending=False)
# missing_values=pd.concat([total,percent],axis=1,keys=['total','percent'])
# missing_values.head(20)

# %%
# train.head()

# %%
print('shape of train:',train.shape)
print('shape of test:',test.shape)
print('shape of weather_train:',weather_train.shape)
print('shape of weather_test:',weather_test.shape)
print('shape of building_metadata:',building_met.shape)
# Out:
# shape of train: (20216100, 4)
# shape of test: (41697600, 4)
# shape of weather_train: (139788, 12)
# shape of weather_test: (277243, 12)
# shape of building_metadata: (1449, 6)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %% [markdown]
# **timestamp stores data as strings in a particular format. Year,month,day,time**

# %% [markdown]
# **Apply to_datetime to convert string to object**

# %%
train['timestamp']=pd.to_datetime(train['timestamp'])
test['timestamp']=pd.to_datetime(test['timestamp'])
weather_train['timestamp']=pd.to_datetime(weather_train['timestamp'])
weather_test['timestamp']=pd.to_datetime(weather_test['timestamp'])

building_met['primary_use']=building_met['primary_use'].astype('category')

# %% [markdown]
# **Merging the three dataset to create train set**

# %%
temp=train[['building_id']]
temp=temp.merge(building_met,on='building_id',how='left')
del temp['building_id']
train=pd.concat([train,temp],axis=1)

# %%
train.head()
# Out:
#    building_id  meter  timestamp  ...  square_feet  year_built floor_count
# 0            0      0 2016-01-01  ...         7432      2008.0           4
# 1            1      0 2016-01-01  ...         2720      2004.0           4
# 2            2      0 2016-01-01  ...         5376      1991.0           4
# 3            3      0 2016-01-01  ...        23685      2002.0           4
# 4            4      0 2016-01-01  ...       116607      1975.0           4
#
# [5 rows x 9 columns]

# %%
temp=train[['site_id','timestamp']]
temp=temp.merge(weather_train,on=['site_id','timestamp'],how='left')
del temp['site_id'],temp['timestamp']
train=pd.concat([train,temp],axis=1)

del temp,weather_train

# %%
train.head()
# Out:
#    building_id  meter  timestamp  ...  Month  Day_date    year
# 0            0      0 2016-01-01  ...    1.0       1.0  2016.0
# 1            1      0 2016-01-01  ...    1.0       1.0  2016.0
# 2            2      0 2016-01-01  ...    1.0       1.0  2016.0
# 3            3      0 2016-01-01  ...    1.0       1.0  2016.0
# 4            4      0 2016-01-01  ...    1.0       1.0  2016.0
#
# [5 rows x 19 columns]

# %%
train.shape
# Out:
# (20216100, 19)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20216100 entries, 0 to 20216099
# Data columns (total 19 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   building_id         int64
#  1   meter               int64
#  2   timestamp           datetime64[ns]
#  3   meter_reading       float64
#  4   site_id             int64
#  5   primary_use         category
#  6   square_feet         int64
#  7   year_built          float64
#  8   floor_count         int64
#  9   air_temperature     float64
#  10  cloud_coverage      float64
#  11  dew_temperature     float64
#  12  precip_depth_1_hr   float64
#  13  sea_level_pressure  float64
#  14  wind_direction      float64
#  15  wind_speed          float64
#  16  Month               float64
#  17  Day_date            float64
#  18  year                float64
# dtypes: category(1), datetime64[ns](1), float64(12), int64(5)
# memory usage: 2.7 GB

# %% [markdown]
# **Creating Hour column**

# %%
import numpy as np

train['hour_datetime']=train['timestamp'].dt.hour.astype(np.int8)

del train['timestamp']

# %%
train.head()
# Out:
#    building_id  meter  meter_reading  ...  Day_date    year  hour_datetime
# 0            0      0            0.0  ...       1.0  2016.0              0
# 1            1      0            0.0  ...       1.0  2016.0              0
# 2            2      0            0.0  ...       1.0  2016.0              0
# 3            3      0            0.0  ...       1.0  2016.0              0
# 4            4      0            0.0  ...       1.0  2016.0              0
#
# [5 rows x 19 columns]

# %% [markdown]
# **Looking for missing values**

# %%
total=train.isnull().sum().sort_values(ascending=False)
percent=(train.isnull().sum()/train.isnull().count()).sort_values(ascending=False)
missing_values=pd.concat([total,percent],axis=1,keys=['total','percent'])
missing_values.head(20)
# Out:
#                     total  percent
# cloud_coverage      82890   0.0041
# Day_date            82890   0.0041
# Month               82890   0.0041
# wind_speed          82890   0.0041
# wind_direction      82890   0.0041
# sea_level_pressure  82890   0.0041
# precip_depth_1_hr   82890   0.0041
# dew_temperature     82890   0.0041
# year                82890   0.0041
# air_temperature     82890   0.0041
# primary_use             0   0.0000
# meter                   0   0.0000
# meter_reading           0   0.0000
# site_id                 0   0.0000
# hour_datetime           0   0.0000
# square_feet             0   0.0000
# year_built              0   0.0000
# floor_count             0   0.0000
# building_id             0   0.0000

# %%
train=train.dropna()

# %%
train.describe()
# Out:
#         building_id         meter  ...        year  hour_datetime
# count  2.013321e+07  2.013321e+07  ...  20133210.0   2.013321e+07
# mean   7.974179e+02  6.617699e-01  ...      2016.0   1.150934e+01
# std    4.264339e+02  9.310602e-01  ...         0.0   6.923804e+00
# min    0.000000e+00  0.000000e+00  ...      2016.0   0.000000e+00
# 25%    3.910000e+02  0.000000e+00  ...      2016.0   6.000000e+00
# 50%    8.940000e+02  0.000000e+00  ...      2016.0   1.200000e+01
# 75%    1.176000e+03  1.000000e+00  ...      2016.0   1.800000e+01
# max    1.448000e+03  3.000000e+00  ...      2016.0   2.300000e+01
#
# [8 rows x 18 columns]

# %%
total=train.isnull().sum().sort_values(ascending=False)
percent=(train.isnull().sum()/train.isnull().count()).sort_values(ascending=False)
missing_values=pd.concat([total,percent],axis=1,keys=['total','percent'])
missing_values.head(20)
# Out:
#                     total  percent
# hour_datetime           0      0.0
# air_temperature         0      0.0
# meter                   0      0.0
# meter_reading           0      0.0
# site_id                 0      0.0
# primary_use             0      0.0
# square_feet             0      0.0
# year_built              0      0.0
# floor_count             0      0.0
# cloud_coverage          0      0.0
# year                    0      0.0
# dew_temperature         0      0.0
# precip_depth_1_hr       0      0.0
# sea_level_pressure      0      0.0
# wind_direction          0      0.0
# wind_speed              0      0.0
# Month                   0      0.0
# Day_date                0      0.0
# building_id             0      0.0

# %% [markdown]
# **Before applying pipeline transformation, steam dataset has been separated**

# %%
dataset_steam=train.loc[(train['meter']==2)]

# %%
dataset_steam.shape
# Out:
# (2688755, 19)

# %% [markdown]
# **Deleting outliers**

# %%
# del_rows=dataset_steam.loc[(dataset_steam['site_id']==13) & (dataset_steam['primary_use']=='Education') &  (dataset_steam['building_id']==1099)]
# del_rows

# %%
# del_rows.shape

# %% [markdown]
# del_rows shape = (8783,19)

# %%
dataset_steam=dataset_steam[(dataset_steam.site_id!=13) & (dataset_steam.primary_use!='Education') & (dataset_steam.building_id !=1099)]
dataset_steam
# Out:
#           building_id  meter  meter_reading  ...  Day_date    year  hour_datetime
# 903               751      2         0.0000  ...       1.0  2016.0              0
# 907               754      2         0.0000  ...       1.0  2016.0              0
# 912               758      2       256.1660  ...       1.0  2016.0              0
# 914               759      2       196.8520  ...       1.0  2016.0              0
# 923               765      2       902.8020  ...       1.0  2016.0              0
# ...               ...    ...            ...  ...       ...     ...            ...
# 20216069         1426      2       262.5820  ...      31.0  2016.0             23
# 20216074         1430      2       318.5680  ...      31.0  2016.0             23
# 20216076         1431      2       426.3400  ...      31.0  2016.0             23
# 20216084         1436      2      1274.6600  ...      31.0  2016.0             23
# 20216093         1442      2        55.6241  ...      31.0  2016.0             23
#
# [938514 rows x 19 columns]

# %%
dataset_steam.shape
# Out:
# (938514, 19)

# %%
drop_cols=['meter_reading']

# %%
training_steam=dataset_steam.drop(drop_cols,axis=1)

# %%
target_steam=dataset_steam['meter_reading']

# %%
training_steam.shape
# Out:
# (938514, 18)

# %%
target_steam.shape
# Out:
# (938514,)

# %% [markdown]
# **Apply pipeline transformation to training_chilled_water**

# %%
num_cols=['square_feet','floor_count','air_temperature',
                 'cloud_coverage','dew_temperature','precip_depth_1_hr',
                 'sea_level_pressure','wind_direction','wind_speed']
cat_cols=['primary_use']

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

num_attribs=list(num_cols)
cat_attribs=['primary_use']

num_pipeline=Pipeline([
    ('std_scaler',StandardScaler())
])

full_pipeline=ColumnTransformer([
    ('num',num_pipeline,num_attribs),
    ('cat',OneHotEncoder(),cat_attribs)
])

training_prepared=full_pipeline.fit_transform(training_steam)
#('num',num_pipeline,num_attribs),

# %% [markdown]
# 938514*0.2 = 187703‬///////‬ 938514-187703= 750811

# %%
x_train=training_prepared[:750811]
x_val=training_prepared[750811:]
y_train=target_steam[:750811]
y_val=target_steam[750811:]

# %%
print('shape of x_train:',x_train.shape)
print('shape of x_val:',x_val.shape)
print('shape of y_train:',y_train.shape)
print('shape of y_val:',y_val.shape)
# Out:
# shape of x_train: (750811, 18)
# shape of x_val: (187703, 18)
# shape of y_train: (750811,)
# shape of y_val: (187703,)

# %% [markdown]
# **Working with test set**

# %%
test.head()
# Out:
#    row_id  building_id  meter  timestamp
# 0       0            0      0 2017-01-01
# 1       1            1      0 2017-01-01
# 2       2            2      0 2017-01-01
# 3       3            3      0 2017-01-01
# 4       4            4      0 2017-01-01

# %%
test.shape
# Out:
# (41697600, 4)

# %%
import pandas as pd

temp=test[['building_id']]
temp=temp.merge(building_met,on='building_id',how='left')
del temp['building_id']
test=pd.concat([test,temp],axis=1)

# %%
test.head()
# Out:
#    row_id  building_id  meter  ... square_feet  year_built floor_count
# 0       0            0      0  ...        7432      2008.0           4
# 1       1            1      0  ...        2720      2004.0           4
# 2       2            2      0  ...        5376      1991.0           4
# 3       3            3      0  ...       23685      2002.0           4
# 4       4            4      0  ...      116607      1975.0           4
#
# [5 rows x 9 columns]

# %%
temp=test[['site_id','timestamp']]
temp=temp.merge(weather_test,on=['site_id','timestamp'],how='left')
del temp['timestamp'],temp['site_id']
test=pd.concat([test,temp],axis=1)

del temp,weather_test

# %%
test.head()
# Out:
#    row_id  building_id  meter  timestamp  ...  wind_speed Month  Day_date    year
# 0       0            0      0 2017-01-01  ...         3.6   1.0       1.0  2017.0
# 1       1            1      0 2017-01-01  ...         3.6   1.0       1.0  2017.0
# 2       2            2      0 2017-01-01  ...         3.6   1.0       1.0  2017.0
# 3       3            3      0 2017-01-01  ...         3.6   1.0       1.0  2017.0
# 4       4            4      0 2017-01-01  ...         3.6   1.0       1.0  2017.0
#
# [5 rows x 19 columns]

# %%
import numpy as np

test['hour_datetime']=test['timestamp'].dt.hour.astype(np.int8)

del test['timestamp']

# %%
total=test.isnull().sum().sort_values(ascending=False)
percent=(test.isnull().sum()/test.isnull().count()).sort_values(ascending=False)
missing_values=pd.concat([total,percent],axis=1,keys=['total','percent'])
missing_values.head(20)
# Out:
#                      total   percent
# cloud_coverage      199029  0.004773
# Day_date            199029  0.004773
# Month               199029  0.004773
# wind_speed          199029  0.004773
# wind_direction      199029  0.004773
# sea_level_pressure  199029  0.004773
# precip_depth_1_hr   199029  0.004773
# dew_temperature     199029  0.004773
# year                199029  0.004773
# air_temperature     199029  0.004773
# primary_use              0  0.000000
# building_id              0  0.000000
# meter                    0  0.000000
# site_id                  0  0.000000
# hour_datetime            0  0.000000
# square_feet              0  0.000000
# year_built               0  0.000000
# floor_count              0  0.000000
# row_id                   0  0.000000

# %%
test=test.dropna()

# %%
test.describe()
# Out:
#              row_id   building_id  ...          year  hour_datetime
# count  4.149857e+07  4.149857e+07  ...  4.149857e+07   4.149857e+07
# mean   2.074928e+07  8.066223e+02  ...  2.017500e+03   1.150802e+01
# std    1.197961e+07  4.298097e+02  ...  5.000000e-01   6.924727e+00
# min    0.000000e+00  0.000000e+00  ...  2.017000e+03   0.000000e+00
# 25%    1.037464e+07  4.030000e+02  ...  2.017000e+03   6.000000e+00
# 50%    2.074928e+07  9.000000e+02  ...  2.017000e+03   1.200000e+01
# 75%    3.112393e+07  1.193000e+03  ...  2.018000e+03   1.800000e+01
# max    4.149857e+07  1.448000e+03  ...  2.018000e+03   2.300000e+01
#
# [8 rows x 18 columns]

# %%
test_steam= test.loc[(test['meter']==2)]

# %%
test_steam.shape
# Out:
# (5639006, 19)

# %%
test_drop_cols=['row_id']

# %%
testing=test_steam.drop(test_drop_cols,axis=1)

# %%
testing.shape
# Out:
# (5639006, 18)

# %%
num_cols=['square_feet','floor_count','air_temperature',
                 'cloud_coverage','dew_temperature','precip_depth_1_hr',
                 'sea_level_pressure','wind_direction','wind_speed']
cat_cols=['primary_use']

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

num_attribs=list(num_cols)
cat_attribs=['primary_use']

num_pipeline=Pipeline([
    ('std_scaler',StandardScaler())
])

full_pipeline=ColumnTransformer([
    ('num',num_pipeline,num_attribs),
    ('cat',OneHotEncoder(),cat_attribs)
])

testing_prepared=full_pipeline.fit_transform(testing)
#('num',num_pipeline,num_attribs),

# %%
testing_prepared.shape
# Out:
# (5639006, 18)

# %% [markdown]
# **Learning curve, regularization, learning rate, degree power**

# %% [markdown]
# **Learning rate**

# %%
# m = x_train.shape[0]
# n = x_train.shape[1]

# %%
# y_train = np.expand_dims(y_train, 1)

# %%
# y_train.shape

# %%
# def ComputeCostMulti(x_train,y_train,theta):
#   h=x_train .dot (theta)
#   error= h-y_train
#   J = (1./(2*m)) * ((error.T) .dot (error))

# %%
# def GradientDescentMulti(x_train,y_train, theta, eta, num_iters):
#   J_history=[]
#   for iter in range (1,201):
#     h= x_train.dot(theta)
#     error=h-y_train
#     theta_change = (2./m) * eta * (x_train.T .dot(error))
#     theta=theta-theta_change
#     cost_history=(1./(2*m)) * ((error.T) .dot (error))
#     J_history.append(cost_history)
#   return J_history

# %% [markdown]
# **learning rate =0.01**

# %%
# theta = np.zeros((n,1))
# num_iters=200
# eta = 0.01
# history = GradientDescentMulti(x_train,y_train, theta, eta, num_iters)
# print(history)

# %%
# history = np. array(history)
# history_reshape=np.reshape(history, (200,))

# %% [markdown]
# **Learning rate =0.003**

# %%
# theta = np.zeros((n,1))
# num_iters=200
# eta = 0.003
# history_003 = GradientDescentMulti(x_train,y_train, theta, eta, num_iters)
# #print(history)

# %%
# history_003 = np. array(history_003)
# history_003reshape=np.reshape(history_003, (200,))

# %% [markdown]
# **Learning rate =0.001**

# %%
# theta = np.zeros((n,1))
# num_iters=200
# eta = 0.001
# history_001 = GradientDescentMulti(x_train,y_train, theta, eta, num_iters)
# #print(history)

# %%
# history_001 = np. array(history_001)
# history_001reshape=np.reshape(history_001, (200,))

# %% [markdown]
# **Learning rate =0.03**

# %%
# theta = np.zeros((n,1))
# num_iters=200
# eta = 0.03 
# history_03 = GradientDescentMulti(x_train,y_train, theta, eta, num_iters)
# #print(history)

# %%
# history_03 = np. array(history_03)
# history_03reshape=np.reshape(history_03, (200,))

# %% [markdown]
# **Learning rate = 0.3**

# %%
# theta = np.zeros((n,1))
# num_iters=200
# eta = 0.3
# history_3 = GradientDescentMulti(x_train,y_train, theta, eta, num_iters)
# #print(history)

# %%
# history_3 = np. array(history_3)
# history_3reshape=np.reshape(history_3, (200,))

# %% [markdown]
# **Learning rate =0.1**

# %%
# theta = np.zeros((n,1))
# num_iters=200
# eta = 0.1
# history_1 = GradientDescentMulti(x_train,y_train, theta, eta, num_iters)
# #print(history)

# %%
# history_1 = np. array(history_1)
# history_1reshape=np.reshape(history_1, (200,))

# %%
# import matplotlib.pyplot as plt

# %%
# fig,axes=plt.subplots(1,1,figsize=(6,4),dpi=100)
# plt.plot(range(1,201),history_003reshape,linewidth=2,label='learning rate =0.003')
# plt.plot(range(1,201),history_001reshape,linewidth=2,label='learning rate =0.001')
# plt.plot(range(1,201),history_03reshape,linewidth=2, label = 'learning rate = 0.03')
# plt.plot(range(1,201),history_reshape,linewidth=2, label = 'learning rate = 0.01')
# plt.plot(range(1,201),history_3reshape,linewidth=2, label = 'learning rate = 0.3')
# plt.plot(range(1,201),history_1reshape,linewidth=2, label = 'learning rate = 0.1')
# plt.xlabel('Iterations')
# plt.ylabel('J')
# plt.legend()

# %% [markdown]
# **Learning curve**

# %%
# x_val.shape

# %%
# def ComputeCostMulti(x_train,y_train,theta):
#   h=x_train .dot (theta)
#   error= h-y_train
#   J = (1./(2*m)) * ((error.T) .dot (error))

# %%
# def GradientLearningCurve(x_train,y_train, initial_theta, eta, num_iters):
#   theta=[]
#   for i in range (1,201):
#     h= x_train.dot(initial_theta)
#     error=h-y_train
#     theta_change = (1./m) * eta * (x_train.T .dot(error))
#     theta_grad=theta-theta_change
#     theta.append(theta_grad)
#   return theta

# %%
# def LearningCurveError(X,y,theta):
#   h=X.dot (theta)
#   error= h-y
#   J = (1./(2*m)) * ((error.T) .dot (error))

# %%
# def LearningCurveTrain(X,y,eta,initial_theta,num_iters):
#   train_error=[]
#   for i in range(1,m):
#     theta = GradientLearningCurve(x_train[:i],y_train[:i],initial_theta,eta,num_iters)
#     training_error = LearningCurveError(x_train[:i],y_train[:i],theta)
#     val_error = LearningCurveError(x_val,y_val,theta)
#     train_error.append(training_error)
#     val_error.append(val_error)

#   return train_error
#   return val_error

# %%
# eta = 0.3
# initial_theta=np.zeros((n,1))
# num_iters=200
# train_errors=LearningCurveTrain(x_train,y_train,eta, initial_theta,num_iters)

# %%
# print(train_errors)

# %%
# def LearningCurveTrain(X_train,y_train,x_val,y_val,eta,initial_theta,num_iters):
#   val_error=[]
#   for i in range(1,m):
#     theta = GradientLearningCurve(x_train[:i],y_train[:i],initial_theta,eta,num_iters)
#     #training_error = LearningCurveError(x_train[:i],y_train[:i],theta)
#     validation_error = LearningCurveError(x_val,y_val,theta)
#     train_error.append(training_error)
#     #val_error.append(val_error)
#   return train_error
#   return val_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from math import sqrt

lin_reg=LinearRegression()
lin_reg.fit(x_train,y_train)
lin_predict=lin_reg.predict(x_val)
lin_mse=mean_squared_error(lin_predict,y_val)
lin_rmse=sqrt(lin_mse)
lin_rmse
# Out:
# 791.0600817118814

# %% [markdown]
# Linear regression RMSE 791.0600817118814

# %% [markdown]
# **Applying 2 degree polynomial**

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_features=PolynomialFeatures(degree=2,include_bias=False)
x_poly=poly_features.fit_transform(x_train)
lin_reg=LinearRegression()
lin_reg.fit(x_poly,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x_val_poly=poly_features.transform(x_val)
predict=lin_reg.predict(x_val_poly)
degree2_mse=mean_squared_error(predict,y_val)
degree2_rmse=sqrt(degree2_mse)
degree2_rmse
# Out:
# 2486.5616840162443

# %% [markdown]
# 2nd degree polynomial RMSE 2486.5616840162443

# %% [markdown]
# **Applying 3 degree polynomial. 3 or higher degree polynomial will have to be done through virtual server**

# %%
# from sklearn.preprocessing import PolynomialFeatures

# poly3_features=PolynomialFeatures(degree=3,include_bias=False)
# x_poly=poly3_features.fit_transform(x_train[:1000000])
# lin_reg=LinearRegression()
# lin_reg.fit(x_poly,y_train[:1000000])

# %%
# x_val_poly=poly3_features.transform(x_val)
# predict=lin_reg.predict(x_val_poly)
# degree3_mse=mean_squared_error(predict,y_val)
# degree3rmse=sqrt(degree2_mse)
# degree3_rmse

# %% [markdown]
# **Using grid search with Ridge regression**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
param_grid=[
            {'alpha':[0.001,0.003,0.01,0.03,0.1,0.3,1,3]}
]

ridge_reg=Ridge()

grid_search=GridSearchCV(ridge_reg,param_grid,cv=5,
                         scoring='neg_mean_squared_error',
                         return_train_score=True)

grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'alpha': [0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
grid_search.best_params_
# Out:
# {'alpha': 3}

# %% [markdown]
# Ridge regression alpha=3

# %% [markdown]
# **Ridge regression with alpha=0.001**

# %%
from sklearn.metrics import mean_squared_error

ridge_reg=Ridge(alpha=0.001,solver='cholesky')
ridge_reg.fit(x_train,y_train)
ridge_pred=ridge_reg.predict(x_val)
ridge_mse=mean_squared_error(ridge_pred,y_val)
ridge_rmse=np.sqrt(ridge_mse)
ridge_rmse
# Out:
# 791.0600832177179

# %% [markdown]
# Ridge regression RMSE 791.0600832177179

# %% [markdown]
# **Using grid search with Lasso regression**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

param_grid=[
            {'alpha':[0.001,0.003,0.01,0.03,0.1,0.3,1,3]}
]

lasso_reg=Lasso()

grid_search=GridSearchCV(lasso_reg,param_grid,cv=5,
                         scoring='neg_mean_squared_error',
                         return_train_score=True)

grid_search.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19033122431.61429, tolerance: 18465800.67850901
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30946486001.12137, tolerance: 31047317.404990535
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34047928347.884583, tolerance: 33988649.73279996
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35607621652.35585, tolerance: 35004398.24536983
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34967117789.76573, tolerance: 34376289.70327211
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6907203398.134201, tolerance: 18465800.67850901
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7909531772.953949, tolerance: 31047317.404990535
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8697851666.157196, tolerance: 33988649.73279996
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9089161758.513916, tolerance: 35004398.24536983
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8927928366.03888, tolerance: 34376289.70327211
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7913314787.080078, tolerance: 31047317.404990535
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8702002764.427399, tolerance: 33988649.73279996
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9093284512.498718, tolerance: 35004398.24536983
#   positive)
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=1000, normalize=False, positive=False,
#                              precompute=False, random_state=None,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'alpha': [0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
grid_search.best_params_
# Out:
# {'alpha': 0.1}

# %% [markdown]
# Lasso regression alpha= 0.1

# %% [markdown]
# **Lasso regression with alpha= 0.001**

# %%
from sklearn.linear_model import Lasso

lasso_reg=Lasso(alpha=0.001)
lasso_reg.fit(x_train,y_train)
lasso_pred=lasso_reg.predict(x_val)
lasso_mse=mean_squared_error(lasso_pred,y_val)
lasso_rmse=np.sqrt(lasso_mse)
lasso_rmse
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38911603862.298706, tolerance: 38379079.3535875
#   positive)
# 791.0623472944294

# %% [markdown]
# Lasso regression RMSE 791.0623472944294

# %% [markdown]
# **Grid search with elastic net**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet

param_grid=[
            {'alpha':[0.001,0.003,0.01,0.03,0.1,0.3,1,3]}
]

elastic_reg=ElasticNet()

grid_search=GridSearchCV(elastic_reg,param_grid,cv=5,
                         scoring='neg_mean_squared_error',
                         return_train_score=True)

grid_search.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24914002283.79545, tolerance: 18465800.67850901
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73160275181.03598, tolerance: 31047317.404990535
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99647024817.23724, tolerance: 33988649.73279996
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103101487946.79306, tolerance: 35004398.24536983
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102890076767.78558, tolerance: 34376289.70327211
#   positive)
# GridSearchCV(cv=5, error_score=nan,
#              estimator=ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True,
#                                   l1_ratio=0.5, max_iter=1000, normalize=False,
#                                   positive=False, precompute=False,
#                                   random_state=None, selection='cyclic',
#                                   tol=0.0001, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'alpha': [0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
grid_search.best_params_
# Out:
# {'alpha': 0.003}

# %% [markdown]
# Elastic net alpha=0.003

# %% [markdown]
# **Applying elastic net with alpha=1**

# %%
from sklearn.linear_model import ElasticNet

elastic_reg=ElasticNet(alpha=0.003)
elastic_reg.fit(x_train,y_train)
elastic_pred=elastic_reg.predict(x_val)
elastic_mse=mean_squared_error(elastic_pred,y_val)
elastic_rmse=np.sqrt(elastic_mse)
elastic_rmse
# Out:
# 792.7000748803406

# %% [markdown]
# Elastic net RMSE= 792.7000748803406

# %% [markdown]
# **Batch gradient descent**

# %%
#bias_column_size = x_train.shape[0] 
bias_column_size = 1000000   # when running the full simulation the first bias_column_size will be used But in colab, to accodomate for RAM, the second bias_column_size will be used.

# %%
x_train_b = np.c_ [np.ones((bias_column_size,1)), x_train[:1000000]]# adding the bias column in x_train

# %% [markdown]
# **Using normal equation to get theta and then compare with BGD and SGD,MGD**

# %%
theta_best = np.linalg.inv(x_train_b.T .dot (x_train_b)) .dot(x_train_b.T) .dot (y_train[:1000000])
theta_best

# %%
bias_val_column_size = x_val.shape[0]

# %%
x_val_b = np.c_[np.ones((bias_val_column_size,1)),x_val]

# %% [markdown]
# **Batch gradient descent**

# %%
eta_BGD=0.3
n_iterations = 20
m= 1000000

theta_BGD = np.random.randn(theta_best.shape[0],1)
for iteration in range(n_iterations):
    gradients_BGD = 2/m * x_train_b.T.dot(x_train_b.dot(theta_BGD) - y_train[:1000000])
    theta_BGD = theta_BGD - eta_BGD * gradients_BGD

# %%
theta_BGD

# %% [markdown]
# **Grid search to get the optimal learning rate**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDRegressor

param_grid=[
            {'eta0':[0.001,0.003,0.01,0.03,0.1,0.3,1,3]}
]

sgd_reg=SGDRegressor(max_iter=1000,tol=1e-3,penalty='l2')

grid_search=GridSearchCV(sgd_reg,param_grid,cv=5,
                         scoring='neg_mean_squared_error',
                         return_train_score=True)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=SGDRegressor(alpha=0.0001, average=False,
#                                     early_stopping=False, epsilon=0.1,
#                                     eta0=0.01, fit_intercept=True,
#                                     l1_ratio=0.15, learning_rate='invscaling',
#                                     loss='squared_loss', max_iter=1000,
#                                     n_iter_no_change=5, penalty='l2',
#                                     power_t=0.25, random_state=None,
#                                     shuffle=True, tol=0.001,
#                                     validation_fraction=0.1, verbose=0,
#                                     warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'eta0': [0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
grid_search.best_params_
# Out:
# {'eta0': 0.01}

# %% [markdown]
# **Stochastic gradient descent with eta0=0.001**

# %%
from sklearn.linear_model import SGDRegressor
from sklearn. metrics import mean_squared_error

sgd_reg=SGDRegressor(max_iter=200,tol=1e-3,eta0=0.001)
sgd_reg.fit(x_train,y_train)
sgd_pred=sgd_reg.predict(x_val)
sgd_mse=mean_squared_error(sgd_pred,y_val)
sgd_rmse=np.sqrt(sgd_mse)
sgd_rmse
# Out:
# 791.0337085031528

# %% [markdown]
# Stochastic gradient descent RMSE with eta0=0.001 is 791.0337085031528

# %% [markdown]
# **Support Vector Regressor**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVR

param_grid = [
              {'epsilon':[0.003,0.001,0.03,0.01,0.3,0.1,1,3,10,20,50,100,400,800,1000]}
]

svm_reg = LinearSVR()
grid_search = GridSearchCV(svm_reg,param_grid,
                           scoring ='neg_mean_squared_error',
                           return_train_score =True)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=LinearSVR(C=1.0, dual=True, epsilon=0.0,
#                                  fit_intercept=True, intercept_scaling=1.0,
#                                  loss='epsilon_insensitive', max_iter=1000,
#                                  random_state=None, tol=0.0001, verbose=0),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'epsilon': [0.003, 0.001, 0.03, 0.01, 0.3, 0.1, 1, 3,
#                                       10, 20, 50, 100, 400, 800, 1000]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
grid_search.best_params_
# Out:
# {'epsilon': 400}

# %% [markdown]
# **from grid search epsilon = 400. LinearSVR with epsilon = 400**

# %%
from sklearn.svm import LinearSVR
from sklearn.metrics import mean_squared_error
from math import sqrt

svm_reg = LinearSVR(epsilon =700)
svm_reg.fit(x_train,y_train)
svm_reg_pred = svm_reg.predict(x_val)
svm_reg_error = mean_squared_error(svm_reg_pred,y_val)
svm_reg_rmse = sqrt(svm_reg_error)
svm_reg_rmse
# Out:
# 854.3274268856319

# %% [markdown]
# LinearSVR with epsilon 1000 RMSE = 854.3274268856319

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = [
              {'epsilon':[10,20,50,100,400,800,1000]},
              {'degree':[2,3,4,5]},
              {'C':[0.003,0.001,0.03,0.01]} #,20,50,100,400,800,1000
]

svm_poly_reg = SVR(kernel = 'poly')

grid_search = GridSearchCV(svm_poly_reg,param_grid,
                           scoring ='neg_mean_squared_error',
                           return_train_score =True)

grid_search.fit(x_train,y_train)

# %%
grid_search.bet_params_

# %%
from sklearn.svm import SVR
from sklearn.metrics mean_squared_error
from math import sqrt

svm_poly_reg = SVR(kernel ='poly', degree = '', C ='', epislon ='')
svm_poly_reg.fit(x_train,y_train)
svm_poly_pred = svm_poly_reg.pred(x_val)
svm_poly_mse=mean_squared_error(svm_poy_pred,y_val)
svm_poly_rmse = sqrt(svm_poly_mse)
svm_poy_rmse

# %% [markdown]
# **Decision tree**

# %% [markdown]
# **The plan was to let decision tree fit however it wanted and let it overfit, make the figure using export_graphviz and then reducing overfitting**

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

tree_reg=DecisionTreeRegressor()
tree_reg.fit(x_train,y_train)
tree_pred=tree_reg.predict(x_val)
tree_mse=mean_squared_error(tree_pred,y_val)
tree_rmse=np.sqrt(tree_mse)
tree_rmse
# Out:
# 754.4297570354829

# %% [markdown]
# Decision tree RMSE = 413891.5899614067

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

tree_reg=DecisionTreeRegressor(max_depth =200, max_leaf_nodes=200)
tree_reg.fit(x_train,y_train)
tree_pred=tree_reg.predict(x_val)
tree_mse=mean_squared_error(tree_pred,y_val)
tree_rmse=np.sqrt(tree_mse)
tree_rmse
# Out:
# 589.3564560714238

# %% [markdown]
# Decision tree RMSE = 589.7517647881792

# %%
# import os

# PROJECT_ROOT_DIR = "."
# CHAPTER_ID = "decision_trees"
# IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
# os.makedirs(IMAGES_PATH, exist_ok=True)

# %%
# from graphviz import Source
# from sklearn.tree import export_graphviz

# export_graphviz(
#         tree_reg,
#         out_file=os.path.join(IMAGES_PATH, "dec_tree.dot"),
#         feature_names=,
#         rounded=True,
#         filled=True
#     )

# Source.from_file(os.path.join(IMAGES_PATH, "dec_tree.dot"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-a2f15371bee9> in <module>()
#       5         tree_reg,
#       6         out_file=os.path.join(IMAGES_PATH, "dec_tree.dot"),
# ----> 7         feature_names=x_val.columns,
#       8         rounded=True,
#       9         filled=True
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %% [markdown]
# **Ensemble**

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.svm import LinearSVR
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.svm import LinearSVR
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

lin_reg=LinearRegression()
#ridge_reg=Ridge(alpha=0.001,solver='cholesky')
#lasso_reg=Lasso(alpha=0.001)
#elastic_reg=ElasticNet(alpha=0.003)
sgd_reg=SGDRegressor(max_iter=200,tol=1e-3,eta0=0.001)
svm_reg = LinearSVR(epsilon =700)
tree_reg=DecisionTreeRegressor(max_depth =200, max_leaf_nodes=200)

voting_reg=VotingRegressor(
    estimators=[('lr',lin_reg),('svm',svm_reg), ('sgd',sgd_reg),
                ('tree',tree_reg)]
)

voting_reg.fit(x_train,y_train)
# Out:
# VotingRegressor(estimators=[('lr',
#                              LinearRegression(copy_X=True, fit_intercept=True,
#                                               n_jobs=None, normalize=False)),
#                             ('svm',
#                              LinearSVR(C=1.0, dual=True, epsilon=700,
#                                        fit_intercept=True,
#                                        intercept_scaling=1.0,
#                                        loss='epsilon_insensitive',
#                                        max_iter=1000, random_state=None,
#                                        tol=0.0001, verbose=0)),
#                             ('sgd',
#                              SGDRegressor(alpha=0.0001, average=False,
#                                           early_stopping=False, ep...
#                                           validation_fraction=0.1, verbose=0,
#                                           warm_start=False)),
#                             ('tree',
#                              DecisionTreeRegressor(ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=200,
#                                                    max_features=None,
#                                                    max_leaf_nodes=200,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    presort='deprecated',
#                                                    random_state=None,
#                                                    splitter='best'))],
#                 n_jobs=None, weights=None)

# %%
# from sklearn.metrics import accuracy_score

# for reg in (lin_reg,ridge_reg,sgd_reg,svm_reg,tree_reg):
#   reg.fit(x_train[:1000000],y_train[:1000000])
#   pred = reg.predict(x_val)
#   print(reg.__class__.__name__, score(y_val, pred))

# %%
from sklearn.metrics import mean_squared_error

voting_reg_pred=voting_reg.predict(x_val)
voting_reg_mse=mean_squared_error(voting_reg_pred,y_val)
voting_reg_rmse=np.sqrt(voting_reg_mse)
voting_reg_rmse
# Out:
# 716.1177223645493

# %% [markdown]
# Voting regressor RMSE 716.1177223645493

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid=[
            {'n_estimators':[3,10,30,100,400,500]}
]

forest_reg=RandomForestRegressor(max_depth =200, max_leaf_nodes=1000)

grid_search=GridSearchCV(forest_reg,param_grid,cv=5,
                         scoring='neg_mean_squared_error',
                         return_train_score=True)

grid_search.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-99-1c1cbdab573d> in <module>()
#      12                          return_train_score=True)
#      13
# ---> 14 grid_search.fit(x_train[:1000000],y_train[:1000000])
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     381                     verbose=self.verbose, class_weight=self.class_weight,
#     382                     n_samples_bootstrap=n_samples_bootstrap)
# --> 383                 for i, t in enumerate(trees))
#     384
#     385             # Collect newly grown trees
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     163             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     164
# --> 165         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     166     else:
#     167         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1223             sample_weight=sample_weight,
#    1224             check_input=check_input,
# -> 1225             X_idx_sorted=X_idx_sorted)
#    1226         return self
#    1227
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     365                                            min_impurity_split)
#     366
# --> 367         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     368
#     369         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
grid_search.best_estimator_

# %%
from sklearn. ensemble import RandomForestRegressor

forest_reg=RandomForestRegressor(n_estimators=150,max_features=9,n_jobs=-1)
forest_reg.fit(x_train,y_train)

# %% [markdown]
# **BaggingRegressor**

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor

bag_reg= BaggingRegressor(
    DecisionTreeRegressor(max_depth =200, max_leaf_nodes=200),n_estimators =1000,
    max_samples=2000, bootstrap =True, n_jobs=-1 
)

# %%
from math import sqrt

bag_reg.fit(x_train,y_train)
bag_pred= bag_reg.predict(x_val)
bag_mse=mean_squared_error(y_val,bag_pred)
bag_rmse =sqrt(bag_mse)

# %%
bag_rmse
# Out:
# 598.2354350650344

# %% [markdown]
# Bagging regressor RMSE = 598.2354350650344

# %% [markdown]
# **RandomFOrest**

# %% [markdown]
# **Gardient boosting**

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

gbrt = GradientBoostingRegressor(max_depth =200, max_leaf_nodes=200,n_estimators=500,min_samples_leaf=1000,max_features =9,  random_state=42)
gbrt.fit(x_train, y_train)

errors = [mean_squared_error(y_val, y_pred)
          for y_pred in gbrt.staged_predict(x_val)]
bst_n_estimators = np.argmin(errors) + 1

gbrt_best = GradientBoostingRegressor(max_depth=200, n_estimators=bst_n_estimators, random_state=42)
gbrt_best.fit(x_train[:1000000], y_train[:1000000])

# %% [markdown]
# **Originally x_train, y_train was as it is. For including test set x_train[:1000000], y_train[:1000000] was added**

# %%
from math import sqrt

gbrt_best_pred=gbrt_best.predict(x_val)
gbrt_best_mse=mean_squared_error(gbrt_best_pred,y_val)
gbrt_best_rmse = sqrt(gbrt_best_mse)
gbrt_best_rmse
# Out:
# 738.5036419960563

# %% [markdown]
# gradient boosting RMSE with max_depth=200, max_leaf_nodes=200,n_estimators=500,random_state=738.5036419960563/////

# %% [markdown]
# **Making test set predictions**

# %%
gbrt_best_test= gbrt_best.predict(testing_prepared)
#tree_reg_test= tree_reg.predict(testing_prepared)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-c068d86ab831> in <module>()
# ----> 1 gbrt_best_test= gbrt_best.predict(testing_prepared)
#       2 #tree_reg_test= tree_reg.predict(testing_prepared)
#
# NameError: name 'gbrt_best' is not defined

# %% [markdown]
# **Saving test set predictions**

# %%
steam_preds = pd.DataFrame({'row_id':test_steam['row_id'],
                            'meter_reading':tree_reg_test})
steam_preds.head()

# %%
file_name='steam_preds.csv'
steam_preds.to_csv(file_name,index=False)
print('Saved file:'+file_name)

# %%
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.model_selection import GridSearchCV

# param_grid=[
#             {'n_estimators':[3,10,30,100]}
# ]

# forest_reg=RandomForestRegressor()

# grid_search=GridSearchCV(forest_reg,param_grid,cv=5,
#                          scoring='neg_mean_squared_error',
#                          return_train_score=True)

# grid_search.fit(x_train[:90000],y_train[:90000])

# %%
# grid_search.best_estimator_

# %%
# from sklearn. ensemble import RandomForestRegressor

# forest_reg=RandomForestRegressor(n_estimators=150,max_features=9,n_jobs=-1)
# forest_reg.fit(x_train[:1000000],y_train[:1000000])

# %%
# pred=forest_reg.predict(x_val)

# %%
# mse=mean_squared_error(pred,y_val)
# mse

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

def plot_learning_curves(model, X, y):
    chilled_x_train=training_prepared[:10000]
    chilled_x_val=training_prepared[10000:20000]
    chilled_y_train=target_chilled_water[:10000]
    chilled_y_val=target_chilled_water[10000:20000]
    train_errors, val_errors = [], []
    for m in range(1, len(chilled_x_train)):
        model.fit(chilled_x_train[:m], chilled_y_train[:m])
        y_train_predict = model.predict(chilled_x_train[:m])
        y_val_predict = model.predict(chilled_x_val)
        y_train_mse=mean_squared_error(chilled_y_train[:m], y_train_predict)
        y_val_mse=mean_squared_error(chilled_y_val, y_val_predict)
        train_errors.append(y_train_mse)
        val_errors.append(y_val_mse)
        for index in enumerate(train_errors):
          print(index)
        

    plt.plot(np.sqrt(train_errors), "r-+", linewidth=2, label="train")
    plt.plot(np.sqrt(val_errors), "b-", linewidth=3, label="val")   
    plt.xlabel("Training set size", fontsize=14) 
    plt.ylabel("RMSE", fontsize=14)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
plot_learning_curves(lin_reg, training_prepared, target_chilled_water)                           
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# (1273, 370.6650839866035)
# (1274, 372.2698383768838)
# (1275, 372.3391000187233)
# (1276, 372.0638486993197)
# (1277, 371.9180670164373)
# (1278, 371.8120716348172)
# (1279, 371.6377051771557)
# (1280, 371.56963697347487)
# (1281, 374.0410238372271)
# (1282, 373.8135984344097)
# (1283, 373.72687855916615)
# (1284, 373.6071832379633)
# (1285, 373.6594823367208)
# (1286, 380.7668186854669)
# (1287, 380.6277782027455)
# (1288, 380.50526796955046)
# (1289, 380.38147548446665)
# (1290, 380.31206201658557)
# (1291, 380.1220306768608)
# (1292, 379.99839666360174)
# (1293, 379.8763749639019)
# (1294, 380.1082665224475)
# (1295, 379.9669257795524)
# (1296, 379.98282004660587)
# (1297, 379.93814474220835)
# (1298, 379.84521979880014)
# (1299, 379.72934182102983)
# (1300, 379.61089349913425)
# (1301, 379.46821141445406)
# (1302, 379.4297453306196)
# (1303, 379.33353889763805)
# (1304, 379.18844135209673)
# (1305, 379.05871848614134)
# (1306, 379.0315806323995)
# (1307, 378.82099590175415)
# (1308, 378.6601025000139)
# (1309, 378.49634681882554)
# (1310, 378.40239434269614)
# (1311, 378.2749697435645)
# (1312, 378.1729329795077)
# (1313, 378.03949190716884)
# (1314, 377.94000865887966)
# (1315, 377.933161096075)
# (1316, 377.7801640441696)
# (1317, 377.6749723655612)
# (1318, 377.53772862432385)
# (1319, 377.4452448620474)
# (1320, 377.30447974776223)
# (1321, 377.24553941902167)
# (1322, 377.02589152424133)
# (1323, 376.8998653475737)
# (1324, 376.7792747664756)
# (1325, 376.6374214087757)
# (1326, 376.4967937301925)
# (1327, 376.3899230688807)
# (1328, 376.32763449410635)
# (1329, 376.2163552952411)
# (1330, 376.0892898369297)
# (1331, 375.95374307416955)
# (1332, 375.82033719657903)
# (1333, 375.68005477815205)
# (1334, 375.5681346854326)
# (1335, 375.4170915525301)
# (1336, 375.31094785850325)
# (1337, 375.262742689244)
# (1338, 375.1226886455755)
# (1339, 374.98439089761837)
# (1340, 374.9019417724737)
# (1341, 374.8669942774731)
# (1342, 374.65946637212693)
# (1343, 374.58202188832274)
# (1344, 374.36681369385997)
# (1345, 374.3667090692657)
# (1346, 374.2524876176792)
# (1347, 374.06361353218006)
# (1348, 373.95813246738294)
# (1349, 373.78923484695486)
# (1350, 373.65624937029935)
# (1351, 373.536157237781)
# (1352, 373.3851755062365)
# (1353, 373.24744104207633)
# (1354, 373.19431033193956)
# (1355, 372.98544688962244)
# (1356, 372.86281270081884)
# (1357, 372.73576725455723)
# (1358, 372.6002281658414)
# (1359, 372.46327350473524)
# (1360, 372.326573997271)
# (1361, 372.18986548062645)
# (1362, 372.13578458052825)
# (1363, 371.9286730820126)
# (1364, 371.84080876607385)
# (1365, 371.7856687729634)
# (1366, 371.7189652073171)
# (1367, 371.68472091812436)
# (1368, 371.57671777641997)
# (1369, 371.5864378914026)
# (1370, 371.4352327157029)
# (1371, 371.3340567021452)
# (1372, 371.2063557741427)
# (1373, 371.1128715709534)
# (1374, 371.0444654857334)
# (1375, 370.991328928403)
# (1376, 370.8495233991351)
# (1377, 370.8537520380081)
# (1378, 370.6504681307939)
# (1379, 370.53002953220494)
# (1380, 370.47485159451315)
# (1381, 370.33447244519596)
# (1382, 370.25572301226174)
# (1383, 370.20205264746585)
# (1384, 370.12083909100005)
# (1385, 370.00166271735867)
# (1386, 369.9867360224424)
# (1387, 369.86279558758093)
# (1388, 369.7517051480471)
# (1389, 369.63553799235467)
# (1390, 369.53172698363886)
# (1391, 369.4068835186828)
# (1392, 369.32885418892175)
# (1393, 369.2320069046238)
# (1394, 369.12247050970507)
# (1395, 369.1082555083254)
# (1396, 368.8614676552596)
# (1397, 368.7448143299177)
# (1398, 368.6184633743086)
# (1399, 368.49016680313173)
# (1400, 368.56825192195936)
# (1401, 368.55739801933095)
# (1402, 368.54259186814744)
# (1403, 368.63319558707707)
# (1404, 368.5568860264946)
# (1405, 368.53867341581355)
# (1406, 368.3621222282858)
# (1407, 368.29531632816185)
# (1408, 368.1764580048933)
# (1409, 368.1195801927329)
# (1410, 368.0816333671927)
# (1411, 367.9512705167367)
# (1412, 367.81461101907786)
# (1413, 367.731569145611)
# (1414, 367.57763793930525)
# (1415, 367.59596146248293)
# (1416, 367.4734280899576)
# (1417, 367.3614526080765)
# (1418, 367.2463800695276)
# (1419, 367.15921881750774)
# (1420, 367.1278598402741)
# (1421, 367.039642921271)
# (1422, 366.9526054542575)
# (1423, 366.8697088699111)
# (1424, 366.75572438476115)
# (1425, 366.7244864015683)
# (1426, 366.63931814887763)
# (1427, 366.5383686978862)
# (1428, 366.38581146096703)
# (1429, 366.31411488255253)
# (1430, 366.24349467772794)
# (1431, 366.07687861309614)
# (1432, 366.0047917130602)
# (1433, 365.9447405480456)
# (1434, 365.7750842301654)
# (1435, 365.7048949715822)
# (1436, 365.61730967295614)
# (1437, 365.5442543923506)
# (1438, 365.3837966325479)
# (1439, 365.29629251168205)
# (1440, 365.2027012891012)
# (1441, 365.10890945484306)
# (1442, 365.0783327922189)
# (1443, 364.9356176711925)
# (1444, 364.8472924426234)
# (1445, 364.73942849072273)
# (1446, 364.6047219728226)
# (1447, 364.57205468327925)
# (1448, 364.45771578721843)
# (1449, 364.30487026312505)
# (1450, 364.224246568568)
# (1451, 364.09887464077576)
# (1452, 363.9957618911264)
# (1453, 363.92058089185605)
# (1454, 363.7849166020955)
# (1455, 363.6705345784478)
# (1456, 363.594819360929)
# (1457, 363.48012139170766)
# (1458, 363.33470847149596)
# (1459, 363.24341735687364)
# (1460, 363.13286611801976)
# (1461, 363.0499006407366)
# (1462, 362.9419138637233)
# (1463, 362.9977577692149)
# (1464, 362.79821375735196)
# (1465, 362.70974574976424)
# (1466, 362.6323060353833)
# (1467, 362.5177077431919)
# (1468, 362.399149861978)
# (1469, 362.29571930145806)
# (1470, 362.2276076068878)
# (1471, 362.2445408052233)
# (1472, 362.22451708320546)
# (1473, 362.0445056049041)
# (1474, 362.0485485485271)
# (1475, 361.9459265309648)
# (1476, 361.8169867518706)
# (1477, 361.80087980955653)
# (1478, 361.6724032035346)
# (1479, 361.5840131767578)
# (1480, 361.4340199099597)
# (1481, 361.34043182755096)
# (1482, 361.39836878190147)
# (1483, 361.2467578350202)
# (1484, 361.21395497016977)
# (1485, 361.1389774669784)
# (1486, 360.9518673229885)
# (1487, 360.8334944026553)
# (1488, 360.7129342436981)
# (1489, 360.64732083980414)
# (1490, 360.5080173798748)
# (1491, 360.3641026496369)
# (1492, 360.24360563893003)
# (1493, 360.15783189535057)
# (1494, 360.09188252289897)
# (1495, 359.9222196155847)
# (1496, 359.8042626171176)
# (1497, 359.68292831337726)
# (1498, 359.5755299841567)
# (1499, 359.45778390124417)
# (1500, 359.3469421721415)
# (1501, 359.1997984123166)
# (1502, 359.1205564429189)
# (1503, 359.0050290325419)
# (1504, 358.88601185182705)
# (1505, 359.4300742293995)
# (1506, 359.40610618879333)
# (1507, 359.2241512721296)
# (1508, 359.1134154640859)
# (1509, 358.97775858092564)
# (1510, 358.8619311765298)
# (1511, 358.74998323099925)
# (1512, 358.63144361788346)
# (1513, 358.5229296551825)
# (1514, 358.4152199582005)
# (1515, 358.36466657087124)
# (1516, 358.18220011935443)
# (1517, 358.06957775829545)
# (1518, 357.9517441744939)
# (1519, 357.83400530462603)
# (1520, 357.8732976847881)
# (1521, 357.7132688860081)
# (1522, 357.59618011721716)
# (1523, 357.5925133938287)
# (1524, 357.4760284333776)
# (1525, 357.35894336475997)
# (1526, 357.51488854677757)
# (1527, 357.44836181730005)
# (1528, 357.29424461445757)
# (1529, 357.19477315569463)
# (1530, 357.13923754091553)
# (1531, 356.9854126084864)
# (1532, 357.10421691413774)
# (1533, 356.83540053100603)
# (1534, 356.7690086914214)
# (1535, 356.642524524457)
# (1536, 356.56886668623997)
# (1537, 356.42466051769105)
# (1538, 356.27374597393816)
# (1539, 356.17793978584297)
# (1540, 356.08857493166477)
# (1541, 356.0683304093431)
# (1542, 355.99090578802463)
# (1543, 355.88926148064735)
# (1544, 355.7746939278173)
# (1545, 355.66441208091055)
# (1546, 355.55079148716356)
# (1547, 355.4639085776387)
# (1548, 355.3491751377133)
# (1549, 355.2444823722521)
# (1550, 355.2025591434925)
# (1551, 355.1966523172488)
# (1552, 354.98508167448665)
# (1553, 354.85967611669736)
# (1554, 354.82415895225216)
# (1555, 354.71765312691565)
# (1556, 354.5436446544922)
# (1557, 354.40408439049065)
# (1558, 354.30210308930896)
# (1559, 354.15987368370133)
# (1560, 354.0956119493124)
# (1561, 353.9752752061848)
# (1562, 353.8819009035062)
# (1563, 353.7512572063753)
# (1564, 353.66405660689634)
# (1565, 353.5635326711631)
# (1566, 353.53736531442985)
# (1567, 353.3595114280686)
# (1568, 353.3683060036651)
# (1569, 353.1983754513568)
# (1570, 353.1842168615081)
# (1571, 352.99382466137115)
# (1572, 352.8828216905868)
# (1573, 352.7609253270545)
# (1574, 352.9645914158739)
# (1575, 352.8570151536323)
# (1576, 352.7455062002192)
# (1577, 352.63389312479546)
# (1578, 352.5393197059668)
# (1579, 352.74779086773196)
# (1580, 352.88620042312414)
# (1581, 352.91525265620425)
# (1582, 352.9563723182017)
# (1583, 353.0170722312415)
# (1584, 352.94371385471595)
# (1585, 352.9271562729663)
# (1586, 353.0362703951219)
# (1587, 353.07309249398963)
# (1588, 352.9542330705796)
# (1589, 352.8778801271137)
# (1590, 352.751605565283)
# (1591, 352.64412388598254)
# (1592, 352.7230346570979)
# (1593, 352.6767949144006)
# (1594, 352.52639519716445)
# (1595, 352.39490807375114)
# (1596, 352.4446053160014)
# (1597, 352.2080095349001)
# (1598, 352.1165035022265)
# (1599, 352.0429874145741)
# (1600, 351.8807381059837)
# (1601, 351.86324734308135)
# (1602, 351.71130102315686)
# (1603, 351.6028473701912)
# (1604, 351.49482523263055)
# (1605, 351.4344535176719)
# (1606, 351.27623490282156)
# (1607, 351.1686965074097)
# (1608, 351.063032700492)
# (1609, 350.95005522309714)
# (1610, 350.84677333955426)
# (1611, 350.77113203804146)
# (1612, 350.75021888620813)
# (1613, 350.5981966757642)
# (1614, 350.5592893889998)
# (1615, 350.4767697062214)
# (1616, 350.2543852062883)
# (1617, 350.1855458152888)
# (1618, 350.0517277177073)
# (1619, 350.0497553081103)
# (1620, 349.9351583443606)
# (1621, 349.75738573109595)
# (1622, 349.6496227103676)
# (1623, 349.6036589378013)
# (1624, 350.014337456372)
# (1625, 349.910869448125)
# (1626, 349.87589726042404)
# (1627, 349.7138858931692)
# (1628, 349.59249635989033)
# (1629, 349.49528823420286)
# (1630, 349.63238562861414)
# (1631, 349.52109804654856)
# (1632, 349.4399425926941)
# (1633, 349.4421720940291)
# (1634, 349.2844751811014)
# (1635, 349.2216199862367)
# (1636, 349.1048253410005)
# (1637, 349.1069359349524)
# (1638, 349.08573783714695)
# (1639, 349.0121572826095)
# (1640, 348.87267537629936)
# (1641, 348.84622689739894)
# (1642, 348.74073933710054)
# (1643, 348.55797677797153)
# (1644, 348.4656825784731)
# (1645, 348.4413702865432)
# (1646, 348.33605016323384)
# (1647, 348.261863354648)
# (1648, 348.1356944134072)
# (1649, 348.030234046573)
# (1650, 347.9410431090995)
# (1651, 347.82496257573933)
# (1652, 347.72039187945023)
# (1653, 347.61544148729)
# (1654, 347.5293691967192)
# (1655, 347.49066012233675)
# (1656, 347.32016657356843)
# (1657, 347.2566312727994)
# (1658, 347.18018549074486)
# (1659, 347.025450917591)
# (1660, 347.0282063763104)
# (1661, 346.96630249785704)
# (1662, 346.86200979729074)
# (1663, 346.82333924390247)
# (1664, 347.00138038995357)
# (1665, 346.9080304102598)
# (1666, 346.7820173532148)
# (1667, 346.68186024747126)
# (1668, 346.65113288297823)
# (1669, 346.4877967640428)
# (1670, 346.4965894268725)
# (1671, 346.3688738617189)
# (1672, 346.2753847289589)
# (1673, 346.29643112298163)
# (1674, 346.19346315888026)
# (1675, 346.09574170563775)
# (1676, 346.01142019346474)
# (1677, 345.91108563993697)
# (1678, 345.85954511949456)
# (1679, 345.7164899511043)
# (1680, 345.62307731261325)
# (1681, 345.52962191246564)
# (1682, 348.35723050547625)
# (1683, 348.2438937778198)
# (1684, 348.14526159997916)
# (1685, 348.0514417350453)
# (1686, 348.1712298875973)
# (1687, 350.0785533378345)
# (1688, 350.00019378722266)
# (1689, 350.02803429676607)
# (1690, 349.9581689227994)
# (1691, 349.96211002840596)
# (1692, 349.8719605795102)
# (1693, 349.7686774962587)
# (1694, 349.68441201131316)
# (1695, 349.79521996942185)
# (1696, 353.46313930299755)
# (1697, 353.4629408842807)
# (1698, 355.27017309356506)
# (1699, 355.2322131775283)
# (1700, 355.1483984912465)
# (1701, 355.0670366365777)
# (1702, 356.79683605398435)
# (1703, 356.6815212926881)
# (1704, 356.5910227317742)
# (1705, 356.5118459709291)
# (1706, 356.3637569901795)
# (1707, 356.2632846623754)
# (1708, 356.15904441158244)
# (1709, 356.1641138796669)
# (1710, 356.0688875938881)
# (1711, 356.0044760793097)
# (1712, 355.89383786545466)
# (1713, 355.9146515894678)
# (1714, 355.84733823218863)
# (1715, 355.7598872813744)
# (1716, 355.8122829940785)
# (1717, 355.5753504272199)
# (1718, 355.54601444945183)
# (1719, 355.3811895119995)
# (1720, 355.31278990274495)
# (1721, 355.4475140789918)
# (1722, 355.5362018224867)
# (1723, 355.395178474794)
# (1724, 355.3614188358184)
# (1725, 355.2064958621952)
# (1726, 372.45197850401746)
# (1727, 372.3463617786772)
# (1728, 372.9830456342436)
# (1729, 372.8932315263601)
# (1730, 372.80083222352096)
# (1731, 372.72753150729454)
# (1732, 372.597257326552)
# (1733, 372.4934963188431)
# (1734, 372.45039113890266)
# (1735, 374.34772624435055)
# (1736, 374.2429907772965)
# (1737, 374.17752846024064)
# (1738, 374.13145539582007)
# (1739, 374.1439452687286)
# (1740, 376.2843991284545)
# (1741, 376.17926589438383)
# (1742, 376.08377994717756)
# (1743, 375.9876317153629)
# (1744, 375.958510670666)
# (1745, 375.76801466563165)
# (1746, 375.69279412203423)
# (1747, 375.5941816741899)
# (1748, 375.82728443780024)
# (1749, 375.7288136648707)
# (1750, 375.67220886145753)
# (1751, 375.66637147812713)
# (1752, 375.5926292346872)
# (1753, 375.5051682710976)
# (1754, 375.48734396091953)
# (1755, 375.3131864504161)
# (1756, 375.293407249363)
# (1757, 375.1867256068557)
# (1758, 375.14408880574257)
# (1759, 375.1020033021802)
# (1760, 374.92526892339725)
# (1761, 374.8689037193689)
# (1762, 374.7332595640534)
# (1763, 374.68698236109657)
# (1764, 374.56678033188086)
# (1765, 374.4766570778632)
# (1766, 374.40437454492013)
# (1767, 374.31462770577264)
# (1768, 374.2470618859681)
# (1769, 374.1566801309869)
# (1770, 374.1376095360477)
# (1771, 374.12496568492924)
# (1772, 373.99512355272174)
# (1773, 373.97201460139684)
# (1774, 373.94701102709945)
# (1775, 373.70734325499967)
# (1776, 373.6117335584779)
# (1777, 373.52238323552655)
# (1778, 373.4375264146498)
# (1779, 373.33438164265505)
# (1780, 373.23142706894174)
# (1781, 373.2238159273991)
# (1782, 373.11873396353513)
# (1783, 373.12277405100184)
# (1784, 372.9522482743918)
# (1785, 372.8577466634296)
# (1786, 372.76179049656065)
# (1787, 372.74865880654977)
# (1788, 372.64577742014865)
# (1789, 372.49777065477446)
# (1790, 372.4059459511007)
# (1791, 372.3858674890522)
# (1792, 372.2820086977261)
# (1793, 372.2027028031677)
# (1794, 372.2038576599015)
# (1795, 372.0337319180879)
# (1796, 371.98820305071183)
# (1797, 371.8646156198667)
# (1798, 371.7712398016665)
# (1799, 371.6798398786842)
# (1800, 371.6344694167573)
# (1801, 371.61844381829536)
# (1802, 371.43136002314793)
# (1803, 371.3374588301461)
# (1804, 371.2537473428916)
# (1805, 371.1437788832038)
# (1806, 371.04178431958013)
# (1807, 370.9398741972982)
# (1808, 370.85832791682395)
# (1809, 370.788151098988)
# (1810, 370.6602440462964)
# (1811, 370.5719320170826)
# (1812, 370.52350876510195)
# (1813, 370.3674464637884)
# (1814, 370.2660672641403)
# (1815, 370.16511943244194)
# (1816, 370.0746083112378)
# (1817, 370.02291956265975)
# (1818, 369.91635416471814)
# (1819, 369.8263963498507)
# (1820, 369.7981362654269)
# (1821, 369.6960649815251)
# (1822, 369.60321778478925)
# (1823, 369.57640305991106)
# (1824, 369.4502344561069)
# (1825, 369.4898718117829)
# (1826, 369.2693960224332)
# (1827, 369.18745586663357)
# (1828, 369.11278872792394)
# (1829, 369.0307089914754)
# (1830, 368.86408236582787)
# (1831, 368.9162463404534)
# (1832, 368.7828541460352)
# (1833, 368.66792204378754)
# (1834, 368.5675336900961)
# (1835, 368.4823502495702)
# (1836, 368.42575150094444)
# (1837, 368.3373616290963)
# (1838, 368.2876175810629)
# (1839, 368.19232645752396)
# (1840, 368.17883301009766)
# (1841, 368.0748370767835)
# (1842, 368.0030091595977)
# (1843, 367.867147365718)
# (1844, 367.75092951995583)
# (1845, 367.70562235078586)
# (1846, 367.6142132113085)
# (1847, 367.5392551504378)
# (1848, 367.48739483762415)
# (1849, 367.3450451241936)
# (1850, 367.2745023472687)
# (1851, 367.15209883410296)
# (1852, 367.05342714326287)
# (1853, 367.0257408631663)
# (1854, 366.9934507053539)
# (1855, 366.96499128042234)
# (1856, 367.03647820549116)
# (1857, 367.00679764915793)
# (1858, 366.9309561016677)
# (1859, 366.90352628827884)
# (1860, 366.81708928174424)
# (1861, 366.75598359119516)
# (1862, 366.66546246552576)
# (1863, 366.5685449524431)
# (1864, 366.5938557350322)
# (1865, 366.4582109534961)
# (1866, 366.3250996038691)
# (1867, 366.2272837476937)
# (1868, 366.13141833089884)
# (1869, 366.1185910204005)
# (1870, 366.02905503374694)
# (1871, 365.94910521686853)
# (1872, 365.83741309566454)
# (1873, 365.7618141425442)
# (1874, 365.7667678895644)
# (1875, 365.6876719728902)
# (1876, 365.6405713368424)
# (1877, 365.5360164043025)
# (1878, 365.4544829003087)
# (1879, 365.39952367141836)
# (1880, 365.3463945002904)
# (1881, 365.2167071575113)
# (1882, 365.17886500951374)
# (1883, 365.06256354052374)
# (1884, 365.0245649330399)
# (1885, 364.9532426902738)
# (1886, 364.7848378327187)
# (1887, 364.72861280593713)
# (1888, 364.6174380587555)
# (1889, 364.5577697060807)
# (1890, 364.46973687367415)
# (1891, 364.3969493484076)
# (1892, 364.3412836356548)
# (1893, 364.2114939668971)
# (1894, 364.13282423611383)
# (1895, 364.0546418544803)
# (1896, 363.9909679163063)
# (1897, 364.0650238046441)
# (1898, 363.8252406767999)
# (1899, 363.78956989190874)
# (1900, 363.6695543943041)
# (1901, 363.625816402725)
# (1902, 363.43602875877605)
# (1903, 363.4570092304664)
# (1904, 363.3160946009541)
# (1905, 363.2208497585403)
# (1906, 363.13536540160607)
# (1907, 363.0996483452603)
# (1908, 362.9916883390638)
# (1909, 362.90919360411357)
# (1910, 362.81369297606244)
# (1911, 362.71763569836753)
# (1912, 362.6487950386488)
# (1913, 362.5330025096984)
# (1914, 362.4452095933332)
# (1915, 362.3507980617459)
# (1916, 362.29843138412934)
# (1917, 362.16405259573423)
# (1918, 362.07100352924226)
# (1919, 361.9775659948857)
# (1920, 361.88379581828315)
# (1921, 361.81382105452917)
# (1922, 361.7102284741526)
# (1923, 361.6850612583634)
# (1924, 361.5655547675329)
# (1925, 361.5718151050456)
# (1926, 361.5629635738826)
# (1927, 361.4356462903077)
# (1928, 361.44477566733764)
# (1929, 361.34625939505264)
# (1930, 361.2637411504405)
# (1931, 361.253934091745)
# (1932, 361.125662938319)
# (1933, 361.05852362055475)
# (1934, 360.96823538637335)
# (1935, 360.9849483389251)
# (1936, 360.9304593260029)
# (1937, 360.87498267022943)
# (1938, 360.7721197560439)
# (1939, 360.6907649738977)
# (1940, 360.6116787100071)
# (1941, 360.5196596395767)
# (1942, 360.4436907625313)
# (1943, 360.3380238931083)
# (1944, 360.2506691460246)
# (1945, 360.1844927324097)
# (1946, 360.1106787048732)
# (1947, 360.0170770171586)
# (1948, 359.938707636673)
# (1949, 359.8184432683575)
# (1950, 359.76911535657916)
# (1951, 359.6708845212064)
# (1952, 359.6005731854647)
# (1953, 359.48830434731445)
# (1954, 359.4007000011186)
# (1955, 359.29321048227695)
# (1956, 359.2214808800942)
# (1957, 359.1310762271882)
# (1958, 359.03942371236525)
# (1959, 359.451876179226)
# (1960, 359.371307430712)
# (1961, 359.28806653642494)
# (1962, 359.20525238381595)
# (1963, 359.116427265508)
# (1964, 359.02746253323005)
# (1965, 359.00245256811917)
# (1966, 358.8949001822688)
# (1967, 358.80126284574203)
# (1968, 358.71651003429895)
# (1969, 358.5944860404834)
# (1970, 358.5035168425226)
# (1971, 358.4415772500462)
# (1972, 358.3423584154738)
# (1973, 358.209037276995)
# (1974, 358.2540636169005)
# (1975, 358.13144201352816)
# (1976, 358.04165517106804)
# (1977, 358.0605489980316)
# (1978, 357.9701044414134)
# (1979, 357.90444104828225)
# (1980, 358.0261396979997)
# (1981, 357.9493160825259)
# (1982, 357.87669471065027)
# (1983, 357.7801473348079)
# (1984, 357.70269120052023)
# (1985, 357.62677181342093)
# (1986, 357.57783189803575)
# (1987, 357.5913554299708)
# (1988, 357.44212980649905)
# (1989, 357.3533267242827)
# (1990, 357.2648322787478)
# (1991, 357.19696081718195)
# (1992, 357.0987862524884)
# (1993, 357.02856741469344)
# (1994, 357.0519962004602)
# (1995, 356.9529433310328)
# (1996, 356.86051442582766)
# (1997, 356.8281553726848)
# (1998, 356.7037920601719)
# (1999, 356.6275765494796)
# (2000, 356.5275029575438)
# (2001, 356.4737055953636)
# (2002, 356.3940502303854)
# (2003, 356.29267342263944)
# (2004, 356.2224009127168)
# (2005, 356.1883885864727)
# (2006, 356.08582171020964)
# (2007, 356.05738331723256)
# (2008, 355.9348895888511)
# (2009, 355.83257369785383)
# (2010, 355.81358092190675)
# (2011, 355.658814294282)
# (2012, 355.57084073384254)
# (2013, 355.4958023772881)
# (2014, 355.4481280298218)
# (2015, 355.31330689371026)
# (2016, 355.24728821665764)
# (2017, 355.13817045645584)
# (2018, 355.0634378457177)
# (2019, 355.01714374397875)
# (2020, 354.90068911045597)
# (2021, 354.85207749995845)
# (2022, 354.78084209122477)
# (2023, 354.7200495648686)
# (2024, 354.63662582287316)
# (2025, 354.6152370544242)
# (2026, 354.44966658636764)
# (2027, 354.36701421175627)
# (2028, 354.59424399818056)
# (2029, 354.5085415750571)
# (2030, 354.42125699448735)
# (2031, 354.3348523766782)
# (2032, 354.2625323485843)
# (2033, 354.3994523821627)
# (2034, 354.3071178484236)
# (2035, 354.19160639135305)
# (2036, 354.1836195152796)
# (2037, 354.18140190725586)
# (2038, 354.0480810236375)
# (2039, 353.9801237015668)
# (2040, 353.98257075866974)
# (2041, 354.0849250248089)
# (2042, 353.8669307922955)
# (2043, 353.78294696633276)
# (2044, 353.69731339720397)
# (2045, 353.64707269618646)
# (2046, 353.6618166018858)
# (2047, 353.613465122502)
# (2048, 353.54780362082005)
# (2049, 353.4062470675277)
# (2050, 353.32820840274695)
# (2051, 353.23431783881085)
# (2052, 353.1971831783481)
# (2053, 353.16180993730586)
# (2054, 352.9982534176503)
# (2055, 352.9140036004266)
# (2056, 352.8279421555385)
# (2057, 352.77533094709855)
# (2058, 352.6915048767573)
# (2059, 352.60632527187477)
# (2060, 352.5208198236378)
# (2061, 352.4358988700109)
# (2062, 352.3524867761757)
# (2063, 352.26798106267177)
# (2064, 352.18271776700703)
# (2065, 352.1219442706236)
# (2066, 352.05576935305703)
# (2067, 351.9660417469142)
# (2068, 351.8798206306163)
# (2069, 351.7975693783818)
# (2070, 351.7126250973755)
# (2071, 351.6277465203172)
# (2072, 351.56979492043826)
# (2073, 351.5437280641614)
# (2074, 351.42338429790544)
# (2075, 351.31868481676236)
# (2076, 351.2594930903929)
# (2077, 351.1373367109834)
# (2078, 351.58850280847554)
# (2079, 351.45719633299336)
# (2080, 351.4238734215107)
# (2081, 351.35266994548175)
# (2082, 351.246581094855)
# (2083, 351.12890462061443)
# (2084, 351.20816839959656)
# (2085, 351.1517803857604)
# (2086, 351.07391891859703)
# (2087, 350.98827382003697)
# (2088, 350.9156717103335)
# (2089, 350.9113593452216)
# (2090, 350.8237418915521)
# (2091, 350.7830211679857)
# (2092, 350.80699459534907)
# (2093, 350.7232266059612)
# (2094, 350.63984776031594)
# (2095, 350.5186297008839)
# (2096, 350.4532150405326)
# (2097, 350.41684170449633)
# (2098, 350.30833510170555)
# (2099, 350.3157041902935)
# (2100, 350.2363709386674)
# (2101, 350.1394958509922)
# (2102, 350.0576468262413)
# (2103, 349.9894077393412)
# (2104, 349.91470881767515)
# (2105, 349.82853939545663)
# (2106, 349.728585949258)
# (2107, 349.6813738975592)
# (2108, 349.6446663095767)
# (2109, 349.511021379564)
# (2110, 349.464793491876)
# (2111, 349.359819224801)
# (2112, 349.2961200655449)
# (2113, 349.2029214341713)
# (2114, 349.1447390594698)
# (2115, 349.1214500109786)
# (2116, 349.03898553339326)
# (2117, 349.01628167423553)
# (2118, 349.1202233070072)
# (2119, 349.080926224824)
# (2120, 348.94881470162295)
# (2121, 348.93776509313636)
# (2122, 348.8510997008047)
# (2123, 348.7283717362495)
# (2124, 348.711548052284)
# (2125, 348.66846601007853)
# (2126, 348.55870284528504)
# (2127, 348.5281548867803)
# (2128, 348.4491397554431)
# (2129, 348.3699654379407)
# (2130, 348.3138528150114)
# (2131, 348.25403115537597)
# (2132, 348.1527040738457)
# (2133, 348.0729704575305)
# (2134, 348.03881513292475)
# (2135, 347.94202649538687)
# (2136, 349.85487942473173)
# (2137, 349.75112960089183)
# (2138, 349.68894517901356)
# (2139, 349.60622377775167)
# (2140, 349.6747977165373)
# (2141, 351.0684627983173)
# (2142, 350.9546523813788)
# (2143, 351.0744164641562)
# (2144, 350.96427595590916)
# (2145, 351.00383470762193)
# (2146, 350.9312108905405)
# (2147, 350.871528259822)
# (2148, 350.78057531340426)
# (2149, 350.8505946630749)
# (2150, 353.8785126964341)
# (2151, 353.8065277688708)
# (2152, 355.1728066842253)
# (2153, 355.1906770696959)
# (2154, 355.12756777832317)
# (2155, 355.08816853717104)
# (2156, 356.0345730293075)
# (2157, 355.9312799850829)
# (2158, 355.8815288564698)
# (2159, 355.886263496476)
# (2160, 355.7616885128795)
# (2161, 355.6279094911078)
# (2162, 355.5458284179726)
# (2163, 355.4815342681591)
# (2164, 355.4072683969449)
# (2165, 355.44893822681115)
# (2166, 355.3462348325389)
# (2167, 355.26735628042644)
# (2168, 355.28113002434446)
# (2169, 355.21761995715997)
# (2170, 355.1272127167406)
# (2171, 355.07765689421205)
# (2172, 355.0054659219494)
# (2173, 354.92795532014793)
# (2174, 354.8527241338682)
# (2175, 354.77198212645817)
# (2176, 354.7368165222198)
# (2177, 354.7650675638795)
# (2178, 354.69514161162164)
# (2179, 354.7607752072452)
# (2180, 366.2806841549001)
# (2181, 366.21341089445565)
# (2182, 366.3792419313976)
# (2183, 366.3235318306611)
# (2184, 366.2963625850653)
# (2185, 366.17617629319363)
# (2186, 366.11157450806405)
# (2187, 365.99205993843)
# (2188, 365.9533614048803)
# (2189, 367.46757742131996)
# (2190, 367.39069220998095)
# (2191, 367.36017198224135)
# (2192, 367.31069090658895)
# (2193, 367.3214634991079)
# (2194, 367.9484294370713)
# (2195, 367.8753915045203)
# (2196, 367.7897812924486)
# (2197, 367.71352633770925)
# (2198, 367.6325335694034)
# (2199, 367.5557697057212)
# (2200, 367.47785921709374)
# (2201, 367.39933655065795)
# (2202, 367.5964537611019)
# (2203, 367.4935325289943)
# (2204, 367.4513811667159)
# (2205, 367.4446166908887)
# (2206, 367.3855310592994)
# (2207, 367.31679293564946)
# (2208, 367.24499541172656)
# (2209, 367.16377640914203)
# (2210, 367.1562911693302)
# (2211, 367.05870760595013)
# (2212, 367.0048621822047)
# (2213, 366.9210039587265)
# (2214, 366.8365787145289)
# (2215, 366.78210493667564)
# (2216, 366.7546257317463)
# (2217, 366.6005941582402)
# (2218, 366.54390522281653)
# (2219, 366.4691058954624)
# (2220, 366.4080700728305)
# (2221, 366.3246783879722)
# (2222, 366.2726639881609)
# (2223, 366.20787724372167)
# (2224, 366.17569644289966)
# (2225, 366.15815117453974)
# (2226, 366.08500160696275)
# (2227, 365.9921153349958)
# (2228, 365.9652000446169)
# (2229, 365.8158167068965)
# (2230, 365.7364936355144)
# (2231, 365.6625207755198)
# (2232, 365.59151928869323)
# (2233, 365.50992082612464)
# (2234, 365.4283995002169)
# (2235, 365.3646838348631)
# (2236, 365.3578341901608)
# (2237, 365.2682349713951)
# (2238, 365.2508147680423)
# (2239, 365.110520447854)
# (2240, 365.0326122331619)
# (2241, 364.9649345992202)
# (2242, 364.8881598630835)
# (2243, 364.8774973695979)
# (2244, 364.77502419691785)
# (2245, 364.7146865465268)
# (2246, 364.63847622364324)
# (2247, 364.5587167420819)
# (2248, 364.50794818430177)
# (2249, 364.43054233629516)
# (2250, 364.3931655705306)
# (2251, 364.29653546367837)
# (2252, 364.2158401517904)
# (2253, 364.17669567323236)
# (2254, 364.0960542932432)
# (2255, 363.9639557999088)
# (2256, 363.9388851781991)
# (2257, 363.8186287370005)
# (2258, 363.7801870906661)
# (2259, 363.70191110021784)
# (2260, 363.64165885251407)
# (2261, 363.5476084012172)
# (2262, 363.46076975011965)
# (2263, 363.3871570091031)
# (2264, 363.31072561057925)
# (2265, 363.27151737385054)
# (2266, 363.1387593140297)
# (2267, 363.08002843516016)
# (2268, 363.0000239184839)
# (2269, 362.92009890585587)
# (2270, 362.8459881064876)
# (2271, 362.7803524577568)
# (2272, 362.7243020634778)
# (2273, 362.71421123402587)
# (2274, 362.68679679288755)
# (2275, 362.69731515187266)
# (2276, 362.63786225273265)
# (2277, 362.59964130925465)
# (2278, 362.5399473138418)
# (2279, 362.4664724465692)
# (2280, 362.5092868129925)
# (2281, 362.38562169505997)
# (2282, 362.3870016564595)
# (2283, 362.3196046020256)
# (2284, 362.25938842854885)
# (2285, 362.2268285463611)
# (2286, 362.15034856062437)
# (2287, 362.11379602070144)
# (2288, 362.0178238681694)
# (2289, 361.9810678610742)
# (2290, 361.973109969369)
# (2291, 361.94236738644867)
# (2292, 361.89902512920787)
# (2293, 361.82559804689765)
# (2294, 361.7791331354841)
# (2295, 361.78872097162804)
# (2296, 361.7476325849967)
# (2297, 361.69317576123825)
# (2298, 361.58870885931566)
# (2299, 361.5208741776133)
# (2300, 361.4912317781689)
# (2301, 361.4514767289745)
# (2302, 361.4113395467634)
# (2303, 361.35025725942353)
# (2304, 361.2837210668661)
# (2305, 361.1642347382499)
# (2306, 361.08515296802335)
# (2307, 361.0336198905743)
# (2308, 361.12280370419387)
# (2309, 361.0815934611382)
# (2310, 361.14527967002425)
# (2311, 361.1408438149678)
# (2312, 361.097698431231)
# (2313, 361.0702951145882)
# (2314, 361.0335793385599)
# (2315, 360.993939683188)
# (2316, 360.9612624741481)
# (2317, 360.92265954557354)
# (2318, 360.9022960592536)
# (2319, 360.81977424297446)
# (2320, 360.7481652925554)
# (2321, 360.67395021160263)
# (2322, 360.5754508340965)
# (2323, 360.62990750532504)
# (2324, 360.5824738736942)
# (2325, 360.50792952014086)
# (2326, 360.4530931433911)
# (2327, 360.38334461876156)
# (2328, 360.380899901352)
# (2329, 360.29331811011525)
# (2330, 360.3254011757045)
# (2331, 360.2312186539148)
# (2332, 360.3297989180374)
# (2333, 360.183158133364)
# (2334, 360.1461617417239)
# (2335, 360.0581719878779)
# (2336, 360.00219103662226)
# (2337, 359.9687990556577)
# (2338, 359.9354143173953)
# (2339, 359.79091727575207)
# (2340, 359.79540442798594)
# (2341, 359.7265027553128)
# (2342, 359.69050826378344)
# (2343, 359.6353724008981)
# (2344, 359.555108811122)
# (2345, 359.50138687559485)
# (2346, 359.44841085959644)
# (2347, 359.3883884889099)
# (2348, 359.33688221567843)
# (2349, 359.29646588129185)
# (2350, 359.29203730071225)
# (2351, 359.22021231717787)
# (2352, 359.16042401292975)
# (2353, 359.1146591828303)
# (2354, 359.04009232757517)
# (2355, 359.0245518974807)
# (2356, 358.9370499044545)
# (2357, 358.85122239698126)
# (2358, 358.8101436280456)
# (2359, 358.73999305563603)
# (2360, 358.68288597442984)
# (2361, 358.6801748075841)
# (2362, 358.58215262462073)
# (2363, 358.49903779431713)
# (2364, 358.50814296075447)
# (2365, 358.38586936706514)
# (2366, 358.32628383128963)
# (2367, 358.2496458552928)
# (2368, 358.18925105990604)
# (2369, 358.11477224312705)
# (2370, 358.04067847756687)
# (2371, 357.9655344803038)
# (2372, 357.8902436856628)
# (2373, 357.8148930997397)
# (2374, 357.739556853359)
# (2375, 357.67119903285806)
# (2376, 357.6053935239582)
# (2377, 357.5470931822073)
# (2378, 357.51015452372104)
# (2379, 357.576655794919)
# (2380, 357.56942191806644)
# (2381, 357.56150309044506)
# (2382, 357.4686128683192)
# (2383, 357.3994164431148)
# (2384, 357.34467930380146)
# (2385, 357.306969740287)
# (2386, 357.23566363584564)
# (2387, 357.1552931264032)
# (2388, 357.09303642528374)
# (2389, 357.125432069513)
# (2390, 357.18261155708143)
# (2391, 357.094048446828)
# (2392, 357.11704078278893)
# (2393, 356.98877129803594)
# (2394, 356.93223304209704)
# (2395, 356.8174747553048)
# (2396, 356.7792435549308)
# (2397, 356.7403161289627)
# (2398, 356.6467078343774)
# (2399, 356.57239870164943)
# (2400, 356.50534600367195)
# (2401, 356.4629669441988)
# (2402, 356.3960287603273)
# (2403, 356.3485505128336)
# (2404, 356.24796075927634)
# (2405, 356.1760209477905)
# (2406, 356.115231694127)
# (2407, 356.05987716486595)
# (2408, 355.9715710852523)
# (2409, 355.9185588238601)
# (2410, 355.9157523434234)
# (2411, 355.75815757376216)
# (2412, 355.70448613507017)
# (2413, 356.0247106740836)
# (2414, 355.961819955871)
# (2415, 355.8962620544472)
# (2416, 355.8309447059685)
# (2417, 355.7576093151525)
# (2418, 355.68743755349317)
# (2419, 355.62207568492346)
# (2420, 355.54874241856186)
# (2421, 355.47916112714836)
# (2422, 355.45352349233565)
# (2423, 355.34271761177877)
# (2424, 355.26670883112996)
# (2425, 355.1978666296676)
# (2426, 355.12496544026607)
# (2427, 355.0659052168505)
# (2428, 355.12474148349895)
# (2429, 354.98053434177535)
# (2430, 354.9078651550697)
# (2431, 354.9151292263455)
# (2432, 354.855561304174)
# (2433, 354.77681931182696)
# (2434, 354.9254075429237)
# (2435, 354.8369239144359)
# (2436, 354.7662584745896)
# (2437, 354.71757814470357)
# (2438, 354.65663228075766)
# (2439, 354.59961294400335)
# (2440, 354.543082098133)
# (2441, 354.48673083629404)
# (2442, 354.4316122331709)
# (2443, 354.404228806765)
# (2444, 354.33432554531805)
# (2445, 354.2723156258533)
# (2446, 354.1604635322287)
# (2447, 354.1063862290774)
# (2448, 354.0826622222568)
# (2449, 354.03628681544944)
# (2450, 353.9798877722806)
# (2451, 353.91272136055704)
# (2452, 353.84888350191943)
# (2453, 353.7563017063017)
# (2454, 353.72178095734455)
# (2455, 353.65035075223466)
# (2456, 353.5806042828888)
# (2457, 353.51008522378004)
# (2458, 353.4685441983022)
# (2459, 353.4235040054315)
# (2460, 353.3490192867901)
# (2461, 353.2866295540202)
# (2462, 353.2149366556244)
# (2463, 353.163693363496)
# (2464, 353.05878268739616)
# (2465, 353.00428590802204)
# (2466, 352.9865979817483)
# (2467, 352.8923152042254)
# (2468, 352.7929982818499)
# (2469, 352.72407577508966)
# (2470, 352.6674011752561)
# (2471, 352.59607324979805)
# (2472, 352.53631415326043)
# (2473, 352.47774100416837)
# (2474, 352.43239146652905)
# (2475, 352.3545561238371)
# (2476, 352.38267038095154)
# (2477, 352.2615627022771)
# (2478, 352.2186125232626)
# (2479, 352.14721602230566)
# (2480, 352.0757903136078)
# (2481, 352.02118342060686)
# (2482, 352.15382500695813)
# (2483, 352.1052547488561)
# (2484, 352.0595490267258)
# (2485, 351.9644304316076)
# (2486, 351.90588405997295)
# (2487, 351.8982772756066)
# (2488, 351.87206560500357)
# (2489, 351.80907434122156)
# (2490, 351.7530495590639)
# (2491, 351.75054046093965)
# (2492, 351.68871232322124)
# (2493, 351.6130337009668)
# (2494, 351.69334914919926)
# (2495, 351.53274837023343)
# (2496, 351.46880280945743)
# (2497, 351.4027723090712)
# (2498, 351.33460543694366)
# (2499, 351.2643916994914)
# (2500, 351.2890316738113)
# (2501, 351.2188651745521)
# (2502, 351.14896941244194)
# (2503, 351.0833678981005)
# (2504, 351.01441422613476)
# (2505, 350.9444370469345)
# (2506, 350.8838321428924)
# (2507, 350.81522044824317)
# (2508, 350.75611731356287)
# (2509, 350.6756679545479)
# (2510, 350.61460614687167)
# (2511, 350.57846407081485)
# (2512, 350.4844546003135)
# (2513, 350.42010361209157)
# (2514, 350.35115657630337)
# (2515, 350.2517683344426)
# (2516, 350.30006336111273)
# (2517, 350.1428309951872)
# (2518, 350.1144156541324)
# (2519, 350.0204938310275)
# (2520, 349.9579527842351)
# (2521, 349.8887005733031)
# (2522, 349.8194324497423)
# (2523, 349.75087121376055)
# (2524, 349.6820034502847)
# (2525, 349.6355460381893)
# (2526, 349.54394408776733)
# (2527, 349.4904390333065)
# (2528, 349.44799484260983)
# (2529, 349.36820214296506)
# (2530, 349.28689872681)
# (2531, 349.2204805552193)
# (2532, 349.5664796385882)
# (2533, 349.4889064189198)
# (2534, 349.4281437660262)
# (2535, 349.41002583716494)
# (2536, 349.34637250261903)
# (2537, 349.2178245048862)
# (2538, 349.3133232291111)
# (2539, 349.2366060725914)
# (2540, 349.1540853514818)
# (2541, 349.08888905045893)
# (2542, 349.01984571731316)
# (2543, 349.0556228915186)
# (2544, 348.9223464086124)
# (2545, 348.92876692980906)
# (2546, 348.9296120757957)
# (2547, 348.91853360162173)
# (2548, 348.81638654392873)
# (2549, 348.7538985405549)
# (2550, 348.65904094486626)
# (2551, 348.64452932956533)
# (2552, 348.53783308480996)
# (2553, 348.5101690654102)
# (2554, 348.4420717227354)
# (2555, 348.366463510806)
# (2556, 348.3036635879963)
# (2557, 348.35718793277425)
# (2558, 348.17649474991214)
# (2559, 348.12018780519304)
# (2560, 348.0405365634007)
# (2561, 347.97276064424585)
# (2562, 347.927298246213)
# (2563, 347.87736036981477)
# (2564, 347.77866071398665)
# (2565, 347.7368525679467)
# (2566, 347.6590352378427)
# (2567, 347.6151655159712)
# (2568, 347.55522526885153)
# (2569, 347.52662291809287)
# (2570, 347.4903887232434)
# (2571, 347.42427677239857)
# (2572, 347.52315219569385)
# (2573, 347.47933618207315)
# (2574, 347.43719171829025)
# (2575, 347.3596251408198)
# (2576, 347.32622594473645)
# (2577, 347.21781008926934)
# (2578, 347.18953480579734)
# (2579, 347.12464646875037)
# (2580, 347.08979813066634)
# (2581, 347.06044725842406)
# (2582, 346.9936510081067)
# (2583, 346.9302260502611)
# (2584, 346.8766573255103)
# (2585, 346.9181458263809)
# (2586, 346.74406851254184)
# (2587, 346.6826756566744)
# (2588, 346.61493001468205)
# (2589, 346.6004032123798)
# (2590, 348.3838759879853)
# (2591, 348.3192053258074)
# (2592, 348.25501397948557)
# (2593, 348.24253926479815)
# (2594, 348.30218995360656)
# (2595, 349.1677575554722)
# (2596, 349.1026009014765)
# (2597, 349.1311691199877)
# (2598, 349.09203483163947)
# (2599, 349.08660348035795)
# (2600, 349.01325250911196)
# (2601, 348.9462081115981)
# (2602, 348.8516784259394)
# (2603, 348.9379696717318)
# (2604, 351.3894444131965)
# (2605, 351.2863090035749)
# (2606, 352.4406955347618)
# (2607, 352.4942447355437)
# (2608, 352.4017245425118)
# (2609, 352.3793036877154)
# (2610, 354.6644690942557)
# (2611, 354.5884133948603)
# (2612, 354.59454162957024)
# (2613, 354.4875717406457)
# (2614, 354.39373653546403)
# (2615, 354.33068518603704)
# (2616, 354.2688580001944)
# (2617, 354.2148252061115)
# (2618, 354.1546034696857)
# (2619, 354.15382778212893)
# (2620, 354.08736694602095)
# (2621, 354.05050122945494)
# (2622, 354.0393432102076)
# (2623, 353.9801434104342)
# (2624, 353.9146550584455)
# (2625, 353.85520309704765)
# (2626, 353.7931357926122)
# (2627, 353.7686094846068)
# (2628, 353.6679656544799)
# (2629, 353.62216833616884)
# (2630, 353.5881359268811)
# (2631, 353.56866789355956)
# (2632, 353.5496783247808)
# (2633, 353.51867282239857)
# (2634, 362.9070092490043)
# (2635, 362.8463934569255)
# (2636, 362.8915686476356)
# (2637, 362.8477644463579)
# (2638, 362.7814665072037)
# (2639, 362.71306590845563)
# (2640, 362.6485157509521)
# (2641, 362.5647364391863)
# (2642, 362.588912045074)
# (2643, 363.5890552057872)
# (2644, 363.5506349414407)
# (2645, 363.54472649212966)
# (2646, 363.48448677023646)
# (2647, 363.49400073215963)
# (2648, 364.49831916577995)
# (2649, 364.3809499180362)
# (2650, 364.31546284333643)
# (2651, 364.2497586096346)
# (2652, 364.21020888191197)
# (2653, 364.12742123898533)
# (2654, 364.097287071043)
# (2655, 363.9927858736885)
# (2656, 364.0585546982532)
# (2657, 364.0046115029982)
# (2658, 363.9578490592802)
# (2659, 363.9868031434282)
# (2660, 363.8946391793018)
# (2661, 363.85318706647263)
# (2662, 363.75836457753195)
# (2663, 363.69030141567833)
# (2664, 363.65859085208575)
# (2665, 363.59241106148716)
# (2666, 363.5378844620599)
# (2667, 363.47218065158256)
# (2668, 363.4041780360189)
# (2669, 363.33944966126)
# (2670, 363.2714822860572)
# (2671, 363.2035045061114)
# (2672, 363.1729133249059)
# (2673, 363.08520918991945)
# (2674, 363.0289820747853)
# (2675, 362.96360793095386)
# (2676, 362.90837786198205)
# (2677, 362.8845692284025)
# (2678, 362.8220605025041)
# (2679, 362.7646087110575)
# (2680, 362.7152112059774)
# (2681, 362.64545320492437)
# (2682, 362.5813348982767)
# (2683, 362.5014437017554)
# (2684, 362.43408545347876)
# (2685, 362.3697897832895)
# (2686, 362.30730487815913)
# (2687, 362.23999380890956)
# (2688, 362.1727535555455)
# (2689, 362.11501338198786)
# (2690, 362.1316638730143)
# (2691, 362.0418854980485)
# (2692, 361.95332347467246)
# (2693, 361.8872014160829)
# (2694, 361.85023598213)
# (2695, 361.760429367178)
# (2696, 361.6936180752997)
# (2697, 361.6455473918794)
# (2698, 361.5663759068333)
# (2699, 361.56542467872816)
# (2700, 361.5072739927584)
# (2701, 361.40807300303237)
# (2702, 361.36146231826)
# (2703, 361.29565138098764)
# (2704, 361.36573422150195)
# (2705, 361.3111686874313)
# (2706, 361.24950552248504)
# (2707, 361.18489879908736)
# (2708, 361.1712806502031)
# (2709, 361.0796274070167)
# (2710, 361.01357346495894)
# (2711, 360.9860138919123)
# (2712, 360.8660389326366)
# (2713, 360.81484517735345)
# (2714, 360.74879273254265)
# (2715, 360.80131065569304)
# (2716, 360.65023155006094)
# (2717, 360.5897196613273)
# (2718, 360.48356398502995)
# (2719, 360.41800498285323)
# (2720, 360.3951185733926)
# (2721, 360.3200061687835)
# (2722, 360.228100062776)
# (2723, 360.1802484460186)
# (2724, 360.0964699493622)
# (2725, 360.0326312051623)
# (2726, 360.0479543666851)
# (2727, 359.9008390534278)
# (2728, 359.838015470237)
# (2729, 359.77377369466353)
# (2730, 359.71412892167757)
# (2731, 359.67810837194355)
# (2732, 359.5837955216488)
# (2733, 359.545451487947)
# (2734, 359.53958487445294)
# (2735, 359.3959548849209)
# (2736, 359.33049925255665)
# (2737, 359.3060397289435)
# (2738, 359.2089126710785)
# (2739, 359.1365213413779)
# (2740, 359.07226817939363)
# (2741, 359.0220187691267)
# (2742, 358.98105026594084)
# (2743, 358.9118887316461)
# (2744, 358.8364023486208)
# (2745, 358.77669593901436)
# (2746, 358.7161250313228)
# (2747, 358.65145377489324)
# (2748, 358.60071716825627)
# (2749, 358.55643630883714)
# (2750, 358.4616265943889)
# (2751, 358.3981793574201)
# (2752, 358.3400701826524)
# (2753, 358.2750211033936)
# (2754, 358.21357186887997)
# (2755, 358.1819901755281)
# (2756, 358.1742080386288)
# (2757, 358.01319954946445)
# (2758, 357.96129000065554)
# (2759, 357.9367998822292)
# (2760, 357.8860839287087)
# (2761, 357.8049189803415)
# (2762, 357.78857718821064)
# (2763, 357.733218308012)
# (2764, 357.6754281631818)
# (2765, 357.63659202558307)
# (2766, 357.7746882656485)
# (2767, 357.69447064249783)
# (2768, 357.6394473431387)
# (2769, 357.57519425536174)
# (2770, 357.5209919983627)
# (2771, 357.4517824397845)
# (2772, 357.39238561791586)
# (2773, 357.35191544112115)
# (2774, 357.2831776228468)
# (2775, 357.238252562846)
# (2776, 357.1829309126092)
# (2777, 357.13397828254944)
# (2778, 357.104879128685)
# (2779, 357.0009967724589)
# (2780, 356.9371046264746)
# (2781, 356.8743806415453)
# (2782, 356.81162654244514)
# (2783, 356.88276148163607)
# (2784, 356.81928847175254)
# (2785, 356.7498591983096)
# (2786, 356.6914415911707)
# (2787, 356.66589562150756)
# (2788, 356.5750725565299)
# (2789, 356.5132872739849)
# (2790, 356.513839266708)
# (2791, 356.3857997832315)
# (2792, 356.32511078232943)
# (2793, 356.2957517819226)
# (2794, 356.2435220803369)
# (2795, 356.14426349776033)
# (2796, 356.0923752804658)
# (2797, 356.03540235634614)
# (2798, 355.97867525047764)
# (2799, 355.90087845130944)
# (2800, 355.8373690912353)
# (2801, 355.7838314347565)
# (2802, 355.72133679162073)
# (2803, 355.658274485553)
# (2804, 355.59698605152914)
# (2805, 355.5359323489643)
# (2806, 355.47519855006135)
# (2807, 355.4119544832295)
# (2808, 355.349850776497)
# (2809, 355.2939270166445)
# (2810, 355.2235128399723)
# (2811, 355.160617524218)
# (2812, 355.1515086279009)
# (2813, 355.0904341557724)
# (2814, 355.0933391509403)
# (2815, 354.9740017412182)
# (2816, 354.9070831833796)
# (2817, 354.86062628286004)
# (2818, 354.79829047104766)
# (2819, 354.79136594599424)
# (2820, 354.6872821162797)
# (2821, 354.6426611089829)
# (2822, 354.6136996936335)
# (2823, 354.506002949374)
# (2824, 354.45545561509186)
# (2825, 354.3827949484135)
# (2826, 354.3000407599306)
# (2827, 354.2643449797093)
# (2828, 354.2150881785678)
# (2829, 354.1633255829775)
# (2830, 354.07696220353836)
# (2831, 354.0217488863115)
# (2832, 353.98848817505984)
# (2833, 354.06259559519845)
# (2834, 354.0941690071247)
# (2835, 355.16340694358007)
# (2836, 355.0691869068475)
# (2837, 355.05982892249875)
# (2838, 355.0513459802248)
# (2839, 354.94098250728285)
# (2840, 354.93185973085536)
# (2841, 354.88938022570636)
# (2842, 354.8123634761278)
# (2843, 354.80637679805545)
# (2844, 355.2158902532194)
# (2845, 355.2359856673585)
# (2846, 355.1809556148258)
# (2847, 355.1456253782263)
# (2848, 355.09200342221914)
# (2849, 355.0415038719308)
# (2850, 354.9759055875748)
# (2851, 354.93279391125304)
# (2852, 354.8836781160015)
# (2853, 354.79583993581184)
# (2854, 354.7370041033528)
# (2855, 354.70039366971434)
# (2856, 354.6336171034772)
# (2857, 354.57337171575125)
# (2858, 354.51273472912004)
# (2859, 354.4511480515636)
# (2860, 354.3893726779636)
# (2861, 354.3328300481968)
# (2862, 354.2717462066212)
# (2863, 354.20863390226145)
# (2864, 354.17935677777734)
# (2865, 354.09174530242024)
# (2866, 354.04269748871553)
# (2867, 353.9878316313445)
# (2868, 354.2537551467378)
# (2869, 354.19724349617246)
# (2870, 354.14673524787975)
# (2871, 354.080970726629)
# (2872, 354.0406601488065)
# (2873, 353.9606368395717)
# (2874, 353.90300602445524)
# (2875, 353.8415000020796)
# (2876, 353.78778019658097)
# (2877, 353.7301357122991)
# (2878, 353.68076908785264)
# (2879, 353.61029505353764)
# (2880, 353.528359270133)
# (2881, 353.5002363938012)
# (2882, 353.43041846094854)
# (2883, 353.4719979126017)
# (2884, 353.37385235804214)
# (2885, 353.3016369972442)
# (2886, 353.29634924805487)
# (2887, 353.2357129912507)
# (2888, 353.1746353856712)
# (2889, 353.25779685046064)
# (2890, 353.199485351235)
# (2891, 353.18005347973116)
# (2892, 353.0987776562715)
# (2893, 353.0393598025426)
# (2894, 352.98350617258427)
# (2895, 352.96995971289437)
# (2896, 352.8943768048539)
# (2897, 352.84769956073416)
# (2898, 352.78686917483054)
# (2899, 352.7554973444471)
# (2900, 352.67598608210756)
# (2901, 352.6126365878505)
# (2902, 352.56143504921295)
# (2903, 352.48630238122064)
# (2904, 352.5331499200006)
# (2905, 352.46786592256836)
# (2906, 352.41536628872166)
# (2907, 352.4079172218358)
# (2908, 352.2882429551709)
# (2909, 352.24522394365806)
# (2910, 352.1905655407755)
# (2911, 352.13011335728737)
# (2912, 352.0754979311871)
# (2913, 352.0522617897476)
# (2914, 351.9988320328779)
# (2915, 351.93988872389883)
# (2916, 351.884725126941)
# (2917, 351.8256804371508)
# (2918, 351.7661531863777)
# (2919, 351.7082462486077)
# (2920, 351.6587915875943)
# (2921, 351.5959756474994)
# (2922, 351.53416545511834)
# (2923, 351.4854216252575)
# (2924, 351.41781879249424)
# (2925, 351.3776727855678)
# (2926, 351.32433346636043)
# (2927, 351.27341780622106)
# (2928, 351.22016548057576)
# (2929, 351.1625416898927)
# (2930, 351.1105190788507)
# (2931, 351.06998892364504)
# (2932, 351.01904956976404)
# (2933, 350.9629981963952)
# (2934, 350.91554865804267)
# (2935, 350.89526021006884)
# (2936, 350.7697490238618)
# (2937, 350.939012518265)
# (2938, 350.87238186758543)
# (2939, 350.8223437278856)
# (2940, 350.76270961162817)
# (2941, 350.7500873037513)
# (2942, 350.7139119659619)
# (2943, 350.7146189675312)
# (2944, 350.64695973967423)
# (2945, 350.6060418154483)
# (2946, 350.5916001084187)
# (2947, 350.5403018916155)
# (2948, 350.4924916817745)
# (2949, 350.5217673834666)
# (2950, 350.46367145672184)
# (2951, 350.4066972000591)
# (2952, 350.35221682958394)
# (2953, 350.29412435856943)
# (2954, 350.24876299026806)
# (2955, 350.24189404776064)
# (2956, 350.2290541512239)
# (2957, 350.1168439692491)
# (2958, 350.0724388694999)
# (2959, 350.0364231632162)
# (2960, 350.01759388695854)
# (2961, 349.9129900613701)
# (2962, 349.87285269755546)
# (2963, 349.79858187485763)
# (2964, 349.7411511727318)
# (2965, 349.7049356618315)
# (2966, 349.66790307909577)
# (2967, 349.58053106436796)
# (2968, 349.54638466204915)
# (2969, 349.49743792980723)
# (2970, 349.4363657036626)
# (2971, 349.36272365429664)
# (2972, 349.30628254001266)
# (2973, 349.25371357177966)
# (2974, 349.19965771395204)
# (2975, 349.14170479044896)
# (2976, 349.1194458948874)
# (2977, 349.0322586294553)
# (2978, 348.9742677208339)
# (2979, 348.92079493558106)
# (2980, 348.90740489689716)
# (2981, 348.8109841585616)
# (2982, 348.76345939141805)
# (2983, 348.7038608442813)
# (2984, 348.65053304448867)
# (2985, 348.5977187077839)
# (2986, 348.56009147794964)
# (2987, 348.9344471933379)
# (2988, 348.87276980888896)
# (2989, 348.787247557072)
# (2990, 348.7325756709624)
# (2991, 348.6752117451586)
# (2992, 348.61713032658184)
# (2993, 348.65271596423764)
# (2994, 348.5945977795826)
# (2995, 348.53649728694097)
# (2996, 348.48070852337025)
# (2997, 348.42260359593047)
# (2998, 348.4527094351093)
# (2999, 348.4285848829786)
# (3000, 348.3529580476156)
# (3001, 348.31593562861)
# (3002, 348.28900809313205)
# (3003, 348.23762354950173)
# (3004, 348.1858521255717)
# (3005, 348.13124831881566)
# (3006, 348.0356377277189)
# (3007, 348.0222461220448)
# (3008, 348.0144682968474)
# (3009, 348.00897863487745)
# (3010, 347.8898389963056)
# (3011, 347.8335167439716)
# (3012, 347.7806636582644)
# (3013, 347.7234079388254)
# (3014, 347.6687744148936)
# (3015, 347.63975804970426)
# (3016, 347.5575264932504)
# (3017, 347.47299873872134)
# (3018, 347.44676974150127)
# (3019, 347.37369598453995)
# (3020, 347.39321610646857)
# (3021, 347.307705982376)
# (3022, 347.2984950342916)
# (3023, 347.20886571773724)
# (3024, 347.1691861682667)
# (3025, 347.1155553219309)
# (3026, 347.0614354668979)
# (3027, 347.22211076923026)
# (3028, 347.1679766855576)
# (3029, 347.13102414064326)
# (3030, 347.0889993695477)
# (3031, 347.00584500897986)
# (3032, 346.96902243650493)
# (3033, 346.9177965664332)
# (3034, 346.86297087237017)
# (3035, 346.807225730858)
# (3036, 346.77273865178563)
# (3037, 346.7053771507391)
# (3038, 346.66248377100163)
# (3039, 346.62566660675805)
# (3040, 346.5695866002885)
# (3041, 346.5146089243763)
# (3042, 346.45827298346427)
# (3043, 346.47492283886504)
# (3044, 346.37819038384384)
# (3045, 347.86216035046783)
# (3046, 347.80888747194285)
# (3047, 347.75859663251487)
# (3048, 347.71247733085335)
# (3049, 347.75670651796753)
# (3050, 347.9054070604701)
# (3051, 347.85369238746654)
# (3052, 347.8681570235521)
# (3053, 347.8201815887222)
# (3054, 347.8379696520852)
# (3055, 347.7883897159473)
# (3056, 347.7332274381515)
# (3057, 347.68600859703895)
# (3058, 347.7106144660595)
# (3059, 349.53257238878075)
# (3060, 349.4806571933235)
# (3061, 350.35810299307263)
# (3062, 350.3521617304124)
# (3063, 350.3101348280533)
# (3064, 350.2533481841177)
# (3065, 356.69042552426345)
# (3066, 356.6416961513427)
# (3067, 356.5908286610405)
# (3068, 356.5416113754833)
# (3069, 356.4871942149719)
# (3070, 356.4302182489853)
# (3071, 356.37280812328885)
# (3072, 356.3396298068627)
# (3073, 356.2836489010663)
# (3074, 356.29029551510223)
# (3075, 356.2315142459617)
# (3076, 356.2034584005692)
# (3077, 356.22054750002565)
# (3078, 356.17557220800575)
# (3079, 356.12248926339265)
# (3080, 356.07867360220325)
# (3081, 356.0285153023865)
# (3082, 355.97420532517754)
# (3083, 355.94388264535314)
# (3084, 355.8718641255352)
# (3085, 355.8361776667778)
# (3086, 355.83879786205597)
# (3087, 355.8220080943938)
# (3088, 355.74368289211833)
# (3089, 362.2207068309567)
# ...
# (5665, 349.57488977773556)
# (5666, 349.55989537565097)
# (5667, 349.5502945807623)
# (5668, 349.5086327384007)
# (5669, 349.48468026133065)
# (5670, 349.4590169362427)
# (5671, 349.42828179548576)
# (5672, 349.3986273522583)
# (5673, 349.38312256636186)
# (5674, 349.3592179181203)
# (5675, 349.3407975351142)
# (5676, 349.3228805226925)
# (5677, 349.3506582077795)
# (5678, 349.2513358315755)
# (5679, 349.25816371913874)
# (5680, 349.26524439305746)
# (5681, 349.1866523070676)
# (5682, 349.1561305306573)
# (5683, 349.1300406374006)
# (5684, 349.1013684508883)
# (5685, 349.071594398811)
# (5686, 349.0410437391361)
# (5687, 349.01260690320737)
# (5688, 348.9826955710038)
# (5689, 348.9874015884479)
# (5690, 348.9228579610793)
# (5691, 348.89984739936085)
# (5692, 348.87506016156595)
# (5693, 348.8489452044205)
# (5694, 348.8341072138106)
# (5695, 348.8042547013168)
# (5696, 348.7614389954263)
# (5697, 348.7352384423526)
# (5698, 348.7066102564477)
# (5699, 348.67651230039183)
# (5700, 348.6489950524949)
# (5701, 348.62120938998163)
# (5702, 348.59097751202114)
# (5703, 348.56416029576866)
# (5704, 348.5372015654488)
# (5705, 348.5085248207767)
# (5706, 348.4816091425278)
# (5707, 348.4539344658495)
# (5708, 348.4272015664011)
# (5709, 348.4262020818898)
# (5710, 348.3771317898261)
# (5711, 348.5837464652808)
# (5712, 348.57591625604783)
# (5713, 348.52595841656904)
# (5714, 348.498487640622)
# (5715, 348.48907599275645)
# (5716, 348.4385653335377)
# (5717, 348.4658873002159)
# (5718, 348.4284132722278)
# (5719, 348.39816008286147)
# (5720, 348.39371414235296)
# (5721, 348.33935083826617)
# (5722, 348.35492494886)
# (5723, 348.32554723367616)
# (5724, 348.3020503389001)
# (5725, 348.2969008025273)
# (5726, 348.27015055121126)
# (5727, 348.2447664566899)
# (5728, 348.2620183810841)
# (5729, 348.19112059917586)
# (5730, 348.1612009822026)
# (5731, 348.16816187089887)
# (5732, 348.12126835804406)
# (5733, 348.101812562674)
# (5734, 348.0620592266908)
# (5735, 348.03859685449436)
# (5736, 348.0113886062248)
# (5737, 347.9813188897928)
# (5738, 347.952644837292)
# (5739, 347.9243864658165)
# (5740, 347.896831553564)
# (5741, 347.86733673205686)
# (5742, 347.83976889775977)
# (5743, 347.81466880427973)
# (5744, 347.7846913075543)
# (5745, 347.77102548012334)
# (5746, 347.7437061782407)
# (5747, 347.7144622204133)
# (5748, 347.6866733005982)
# (5749, 347.6595064180364)
# (5750, 347.6320765842348)
# (5751, 347.7097139572301)
# (5752, 347.68206946389034)
# (5753, 347.6587036387673)
# (5754, 347.6287547127715)
# (5755, 347.59867492691023)
# (5756, 347.57132517945064)
# (5757, 347.5540673274821)
# (5758, 347.526079651564)
# (5759, 347.49736526729623)
# (5760, 347.5088610237543)
# (5761, 347.479556450933)
# (5762, 347.45957405962815)
# (5763, 347.43746923197824)
# (5764, 347.4085738456875)
# (5765, 347.38608034757175)
# (5766, 347.34904242574584)
# (5767, 347.3243433845497)
# (5768, 347.2996644072691)
# (5769, 348.10857047503754)
# (5770, 348.0611069280559)
# (5771, 348.0328567157473)
# (5772, 348.0061648102642)
# (5773, 348.05674163572974)
# (5774, 348.4799122150686)
# (5775, 348.46958421359346)
# (5776, 348.4472339160424)
# (5777, 348.4213913228645)
# (5778, 348.4095259195295)
# (5779, 348.38154419680336)
# (5780, 348.36460801357777)
# (5781, 348.3218246055294)
# (5782, 348.36542096486795)
# (5783, 349.3400758444591)
# (5784, 349.4057799956859)
# (5785, 349.7309471765799)
# (5786, 349.72776046859326)
# (5787, 349.70429027118126)
# (5788, 349.6740849566155)
# (5789, 352.15576932716135)
# (5790, 352.1278979060595)
# (5791, 352.0893690362333)
# (5792, 352.05917452459397)
# (5793, 352.03506543077015)
# (5794, 352.00013139549594)
# (5795, 351.96983104993416)
# (5796, 351.9487897271221)
# (5797, 351.9041386273441)
# (5798, 351.9101157737375)
# (5799, 351.8807220272786)
# (5800, 351.8594382819994)
# (5801, 351.86389375103994)
# (5802, 351.87531472920466)
# (5803, 351.8090073478883)
# (5804, 351.7838306761932)
# (5805, 351.7558473817768)
# (5806, 351.7267131015594)
# (5807, 351.76224581452965)
# (5808, 351.6934949348025)
# (5809, 351.6651907031365)
# (5810, 351.6587977353195)
# (5811, 351.63321599773536)
# (5812, 351.6034969843097)
# (5813, 355.31447775769385)
# (5814, 355.2957216331503)
# (5815, 355.41045113324884)
# (5816, 355.3363806064014)
# (5817, 355.30779178978025)
# (5818, 355.27730692716597)
# (5819, 355.2659403003359)
# (5820, 355.22190310048285)
# (5821, 355.21592821473666)
# (5822, 356.016198098691)
# (5823, 355.95346753254944)
# (5824, 355.9295425480171)
# (5825, 355.9161182475349)
# (5826, 355.92487330258274)
# (5827, 356.12342958171365)
# (5828, 356.0929590462754)
# (5829, 356.10938480348995)
# (5830, 356.0356445684546)
# (5831, 356.00530929687113)
# (5832, 355.9764332467123)
# (5833, 355.9735445612236)
# (5834, 355.9196010402796)
# (5835, 355.9379587252037)
# (5836, 355.92318683301414)
# (5837, 355.9701334097242)
# (5838, 355.90783550572456)
# (5839, 355.8852286990567)
# (5840, 355.8586069305805)
# (5841, 355.8432511451609)
# (5842, 355.801076023561)
# (5843, 355.7855439654909)
# (5844, 355.8104767112285)
# (5845, 355.7309038619973)
# (5846, 355.70087538700216)
# (5847, 355.6712966578172)
# (5848, 355.64125868529385)
# (5849, 355.6111716070803)
# (5850, 355.5814076087136)
# (5851, 355.5561033072068)
# (5852, 355.526256696237)
# (5853, 355.49973546016525)
# (5854, 355.46944104025675)
# (5855, 355.4433553492069)
# (5856, 355.4135250792637)
# (5857, 355.3990392445297)
# (5858, 355.3720319671526)
# (5859, 355.47941781583484)
# (5860, 355.3828718974758)
# (5861, 355.3527622185695)
# (5862, 355.3230229965536)
# (5863, 355.29301568732023)
# (5864, 355.26336783890696)
# (5865, 355.2343465724261)
# (5866, 355.2280128950321)
# (5867, 355.1752484578231)
# (5868, 355.1481380755801)
# (5869, 355.1289678280035)
# (5870, 355.10135258812994)
# (5871, 355.07175064867005)
# (5872, 355.04152672403234)
# (5873, 355.0411898871269)
# (5874, 355.01661253915347)
# (5875, 354.952760579898)
# (5876, 354.92326236314125)
# (5877, 354.8932558904206)
# (5878, 354.8779555997506)
# (5879, 354.8495904849555)
# (5880, 354.81960723115185)
# (5881, 354.79711612859876)
# (5882, 354.76696291599416)
# (5883, 354.7398714025475)
# (5884, 354.7111029179313)
# (5885, 354.68258722050217)
# (5886, 354.74391621236845)
# (5887, 354.6265277892096)
# (5888, 354.596418607309)
# (5889, 354.5663733687722)
# (5890, 354.5370500499939)
# (5891, 354.50696585337835)
# (5892, 354.47689332859073)
# (5893, 354.44785765754693)
# (5894, 354.41881757659456)
# (5895, 354.38987915590997)
# (5896, 354.36025710948223)
# (5897, 354.33083179131427)
# (5898, 354.3010169490134)
# (5899, 354.271222988233)
# (5900, 354.3306607434194)
# (5901, 354.265794930263)
# (5902, 354.1840651645841)
# (5903, 354.15445736961885)
# (5904, 354.125065602588)
# (5905, 354.0953397427758)
# (5906, 354.067836796105)
# (5907, 354.0386979565108)
# (5908, 354.01086248861833)
# (5909, 354.00116112525654)
# (5910, 353.9513185929802)
# (5911, 353.9649437475783)
# (5912, 353.93733136368985)
# (5913, 353.9076871702882)
# (5914, 353.89606628910553)
# (5915, 353.84815339103585)
# (5916, 353.82567134504467)
# (5917, 353.7884746548502)
# (5918, 353.7598654368611)
# (5919, 353.7446886028889)
# (5920, 353.7157051638515)
# (5921, 353.6891201452002)
# (5922, 353.6593567999002)
# (5923, 353.6335475750875)
# (5924, 353.60878068541683)
# (5925, 353.5764495439622)
# (5926, 353.5477023254998)
# (5927, 353.5180952421907)
# (5928, 353.5336339299132)
# (5929, 353.4628632772692)
# (5930, 353.4358754358846)
# (5931, 353.40611551034345)
# (5932, 353.37812802246066)
# (5933, 353.34866542326057)
# (5934, 353.32127145168)
# (5935, 353.2920923006971)
# (5936, 353.27485340023287)
# (5937, 353.25275755033164)
# (5938, 353.2447942111204)
# (5939, 353.21760677569137)
# (5940, 353.19136383737384)
# (5941, 353.15584188555107)
# (5942, 353.13973855900025)
# (5943, 353.1145587402935)
# (5944, 353.22055761275493)
# (5945, 353.1914703870186)
# (5946, 353.1603402329509)
# (5947, 353.1377666344159)
# (5948, 353.1291309627556)
# (5949, 353.1124115407634)
# (5950, 353.0544217192425)
# (5951, 353.0308879810104)
# (5952, 353.0152982143163)
# (5953, 353.0016317098803)
# (5954, 352.9883610115766)
# (5955, 352.96023007464026)
# (5956, 352.9336460271424)
# (5957, 352.9044575891634)
# (5958, 352.87501695905655)
# (5959, 352.86709465328875)
# (5960, 352.8164677410022)
# (5961, 352.8525123528322)
# (5962, 352.79261181792685)
# (5963, 352.76549867436637)
# (5964, 352.7361229077989)
# (5965, 352.7067070096657)
# (5966, 352.7231796872329)
# (5967, 352.6536517669052)
# (5968, 352.65189082437706)
# (5969, 352.5952140719523)
# (5970, 352.56712538963006)
# (5971, 352.53983618655315)
# (5972, 352.51590053537564)
# (5973, 352.48992034842223)
# (5974, 352.48439772933307)
# (5975, 352.45277972344445)
# (5976, 352.42345991810885)
# (5977, 352.394207354411)
# (5978, 352.36476352213174)
# (5979, 352.350125816114)
# (5980, 352.32129640660315)
# (5981, 352.2922218515939)
# (5982, 352.3309183513482)
# (5983, 352.2801068399155)
# (5984, 352.2091085607635)
# (5985, 352.180181424646)
# (5986, 352.15143231360884)
# (5987, 352.1327516316249)
# (5988, 352.09270465510144)
# (5989, 352.0635211787986)
# (5990, 352.0440418866049)
# (5991, 352.01606582406293)
# (5992, 351.9881647851289)
# (5993, 351.95882721845527)
# (5994, 351.95354193595637)
# (5995, 351.9121124872124)
# (5996, 351.8832156412426)
# (5997, 351.854548737195)
# (5998, 351.8451232407878)
# (5999, 351.8190845536569)
# (6000, 351.79016452788915)
# (6001, 351.7611842262002)
# (6002, 351.7664180151972)
# (6003, 351.719268975703)
# (6004, 351.6926060312085)
# (6005, 351.66629549242845)
# (6006, 351.65731456504665)
# (6007, 351.6151500660201)
# (6008, 351.59554771525546)
# (6009, 351.5830212000132)
# (6010, 351.5647394042148)
# (6011, 351.6019549212683)
# (6012, 351.60643151656376)
# (6013, 352.014978450374)
# (6014, 351.9822595818685)
# (6015, 352.01195147896607)
# (6016, 351.95580288059364)
# (6017, 351.9265608550093)
# (6018, 351.9251153879585)
# (6019, 351.9014988819523)
# (6020, 351.8722825184389)
# (6021, 351.8445781832037)
# (6022, 351.8640918982763)
# (6023, 351.8774186384223)
# (6024, 351.848222590205)
# (6025, 351.832849512896)
# (6026, 351.8051340217644)
# (6027, 351.77884476133966)
# (6028, 351.7512842723653)
# (6029, 351.73599858698174)
# (6030, 351.69355972239777)
# (6031, 351.66711865714655)
# (6032, 351.6387712720534)
# (6033, 351.6108361177713)
# (6034, 351.5883808512446)
# (6035, 351.5595147575835)
# (6036, 351.5315084763294)
# (6037, 351.5028375326063)
# (6038, 351.47373614044614)
# (6039, 351.4463870893722)
# (6040, 351.41745698715346)
# (6041, 351.4556258735339)
# (6042, 351.36463476346074)
# (6043, 351.3461866632282)
# (6044, 351.30855812782727)
# (6045, 351.2799467719888)
# (6046, 351.39425265118234)
# (6047, 351.36762892220565)
# (6048, 351.34028945860956)
# (6049, 351.31747820727077)
# (6050, 351.2897807662617)
# (6051, 351.2615810342509)
# (6052, 351.2340043578516)
# (6053, 351.20534292860714)
# (6054, 351.1801980065141)
# (6055, 351.1524682812108)
# (6056, 351.1252513556757)
# (6057, 351.0967408810746)
# (6058, 351.0682406218963)
# (6059, 351.0394467394634)
# (6060, 351.01065596454305)
# (6061, 351.0030807919245)
# (6062, 350.9739357153267)
# (6063, 350.9478405349828)
# (6064, 350.9994938604566)
# (6065, 350.94417287646235)
# (6066, 350.8876838244793)
# (6067, 350.92054069288815)
# (6068, 350.894004762294)
# (6069, 350.86510405174926)
# (6070, 350.85490054155423)
# (6071, 350.8169685621159)
# (6072, 350.80077840126825)
# (6073, 350.8380262937409)
# (6074, 350.74905444102586)
# (6075, 350.7550504382703)
# (6076, 350.6985978124215)
# (6077, 350.670713789142)
# (6078, 350.6436927229691)
# (6079, 350.61624215445283)
# (6080, 350.59184967471964)
# (6081, 350.5720399712857)
# (6082, 350.5687256931754)
# (6083, 350.5846452482567)
# (6084, 350.5414497986699)
# (6085, 350.5348493018958)
# (6086, 350.4748771190764)
# (6087, 350.44655740454465)
# (6088, 350.4334728687517)
# (6089, 350.3944039741506)
# (6090, 350.3694229104915)
# (6091, 350.37477921239014)
# (6092, 350.34047557567436)
# (6093, 350.31215343463305)
# (6094, 350.3418203101826)
# (6095, 350.25819773179387)
# (6096, 350.2295460229268)
# (6097, 350.20261549637314)
# (6098, 350.17799297031354)
# (6099, 350.14930065176566)
# (6100, 350.12339584192136)
# (6101, 350.0956603926338)
# (6102, 350.0684216778053)
# (6103, 350.0490438487241)
# (6104, 350.02073306714544)
# (6105, 350.0012618965432)
# (6106, 349.9760365582563)
# (6107, 349.94846710645675)
# (6108, 349.9229889530312)
# (6109, 349.90535629243783)
# (6110, 349.88160280994913)
# (6111, 349.87820643944883)
# (6112, 349.8284483659162)
# (6113, 349.80003594757306)
# (6114, 349.7726511035644)
# (6115, 349.8553081032838)
# (6116, 349.8284712166954)
# (6117, 349.8001370816762)
# (6118, 349.77155666095854)
# (6119, 349.7471669838659)
# (6120, 349.74900977038305)
# (6121, 349.7068342662059)
# (6122, 349.697701421818)
# (6123, 349.64247033936374)
# (6124, 349.6482127294724)
# (6125, 349.62081448641413)
# (6126, 349.57094687710276)
# (6127, 349.5528208924573)
# (6128, 349.5282207677332)
# (6129, 349.50183020235306)
# (6130, 349.47463680946674)
# (6131, 349.4466647467089)
# (6132, 349.41826021179827)
# (6133, 349.475274568693)
# (6134, 349.4128268197279)
# (6135, 349.3591018173921)
# (6136, 349.33222535284364)
# (6137, 349.3040425590069)
# (6138, 349.2756268993709)
# (6139, 349.25345190526565)
# (6140, 349.2265107688605)
# (6141, 349.1980886367959)
# (6142, 349.1701712708117)
# (6143, 349.1480682524414)
# (6144, 349.11877442257475)
# (6145, 349.0974318437155)
# (6146, 349.0945896780524)
# (6147, 349.0415990799496)
# (6148, 349.0133711867339)
# (6149, 349.04101762844186)
# (6150, 348.9569171815661)
# (6151, 348.9441666967038)
# (6152, 348.90867398962024)
# (6153, 348.88521220592077)
# (6154, 348.8569053915323)
# (6155, 348.8285849071359)
# (6156, 348.8011717311864)
# (6157, 348.77299271873636)
# (6158, 348.7447962520264)
# (6159, 348.7309164318248)
# (6160, 348.69947457734105)
# (6161, 348.67120033441444)
# (6162, 348.6560131174996)
# (6163, 348.6150376794456)
# (6164, 348.5878871434877)
# (6165, 348.7397036720851)
# (6166, 348.7121103603985)
# (6167, 348.68385818241654)
# (6168, 348.6556543810129)
# (6169, 348.6276056404068)
# (6170, 348.6014724717839)
# (6171, 348.64263588987626)
# (6172, 348.61531925267644)
# (6173, 348.58809621912104)
# (6174, 348.55987077343264)
# (6175, 348.5651447922232)
# (6176, 348.53107605326187)
# (6177, 348.5030711184129)
# (6178, 348.50698806465545)
# (6179, 348.50262602982906)
# (6180, 348.47461744505046)
# (6181, 348.4469948598333)
# (6182, 348.41927253807773)
# (6183, 348.3911061402287)
# (6184, 348.3634649383631)
# (6185, 348.33587364310546)
# (6186, 348.3355264859983)
# (6187, 348.30745543080855)
# (6188, 348.281691864054)
# (6189, 348.25485797334363)
# (6190, 348.2268332279394)
# (6191, 348.19959768511075)
# (6192, 348.1715071859333)
# (6193, 348.10968773629315)
# (6194, 348.1153486501887)
# (6195, 348.11368329071513)
# (6196, 348.06440205110806)
# (6197, 348.0361975778191)
# (6198, 348.05269180707324)
# (6199, 347.98822047285245)
# (6200, 347.9629384006277)
# (6201, 347.9374385809817)
# (6202, 347.9174052930251)
# (6203, 347.88947572404084)
# (6204, 347.8865163537051)
# (6205, 347.9079121720991)
# (6206, 347.89942590778264)
# (6207, 347.8533540763557)
# (6208, 347.8261025442669)
# (6209, 347.80095730480315)
# (6210, 347.77304466409396)
# (6211, 347.7698881147468)
# (6212, 347.7426180206343)
# (6213, 347.7159229019878)
# (6214, 347.74580928650334)
# (6215, 347.6852951356014)
# (6216, 347.66963775027335)
# (6217, 347.6515572116549)
# (6218, 347.6238959723477)
# (6219, 347.59671750365334)
# (6220, 347.5810895409147)
# (6221, 347.54771065272956)
# (6222, 347.5266401026373)
# (6223, 348.1570328043764)
# (6224, 348.1295318043592)
# (6225, 348.10456757539714)
# (6226, 348.1044041888005)
# (6227, 348.1220276767555)
# (6228, 348.47946810698363)
# (6229, 348.45377647731965)
# (6230, 348.45149452416683)
# (6231, 348.43248681682803)
# (6232, 348.4174627296631)
# (6233, 348.41882247313464)
# (6234, 348.3660221194873)
# (6235, 348.33811063380693)
# (6236, 348.36671263615847)
# (6237, 349.381131426064)
# (6238, 349.3792707840437)
# (6239, 349.7307178658617)
# (6240, 349.72090026103325)
# (6241, 349.6994897808934)
# (6242, 349.65498157044254)
# (6243, 351.8278649935685)
# (6244, 351.8065964620394)
# (6245, 351.8082064354377)
# (6246, 351.7555002749544)
# (6247, 351.7295237629609)
# (6248, 351.70167592418846)
# (6249, 351.67399431313066)
# (6250, 351.6569796628058)
# (6251, 351.63196562397434)
# (6252, 351.62580171854387)
# (6253, 351.6083560035614)
# (6254, 351.582314090808)
# (6255, 351.6160835204314)
# (6256, 351.56943683906997)
# (6257, 351.5434255234988)
# (6258, 351.61345055166356)
# (6259, 351.497546177452)
# (6260, 351.47154602219297)
# (6261, 351.4918789233086)
# (6262, 351.42642135233353)
# (6263, 351.4061091102778)
# (6264, 351.398704532665)
# (6265, 351.37771727028854)
# (6266, 351.3653814617053)
# (6267, 354.56306681314805)
# (6268, 354.5404958733414)
# (6269, 354.56511899080954)
# (6270, 354.56785749615693)
# (6271, 354.5165351178293)
